# %%
import json
import pandas as pd
import numpy as np
from pprint import pprint

# %%
def json_parse(lmi_json):
    with open(lmi_json) as json_file:
         json_data = json.load(json_file)
    return json_data

json_dict = json_parse('infile.json')
pprint(json_dict)
# Out:
# {u'ads': 1,
#  u'adsnip': {u'click_tracking': u'on'},
#  u'compactor': u'on',
#  u'custom': {},
#  u'partials': {u'centerTop_0': {u'description': u'this module is used to set up the dfp slots on the page',
#                                 u'instance': u'ad text-align-center labeled_ad',
#                                 u'name': u'ads/dfpslot',
#                                 u'vars': {u'dfp_ad_unit': u'/51859126/parent_m_ar/gut_890_1',
#                                           u'dfp_div_id': u'300x250_1',
#                                           u'dfp_height': u'250',
#                                           u'dfp_height_2': u'50',
#                                           u'dfp_height_3': u'50',
#                                           u'dfp_width': u'300',
#                                           u'dfp_width_2': u'320',
#                                           u'dfp_width_3': u'300'}},
#                u'centerTop_1': {u'name': u'carousel/ui/title'},
#                u'centerTop_10': {u'description': u'Adds skin-specific Outbrain tags',
#                                  u'name': u'ads/outbrain',
#                                  u'vars': {u'variant': u'gut_890_1',
#                                            u'widget': u'MB_2'}},
#                u'centerTop_11': {u'description': u'This is a latest article by specified root category ordered by published_at desc',
#                                  u'name': u'subject/latest/articles',
#                                  u'vars': {u'count': u'2',
#                                            u'heading': u'Latest Articles',
#                                            u'image_param_string': u'w_300,h_250,c_fill,g_face:center,q_60,f_jpg'}},
#                u'centerTop_12': {u'description': u'this module is used to set up the dfp slots on the page',
#                                  u'instance': u'ad text-align-center adx no-vis-30 labeled_ad sweetart2',
#                                  u'name': u'ads/dfpslot',
#                                  u'vars': {u'dfp_ad_unit': u'/51859126/parent_m_ar/gut_890_3',
#                                            u'dfp_div_id': u'300x250_3',
#                                            u'dfp_height': u'250',
#                                            u'dfp_height_2': u'50',
#                                            u'dfp_height_3': u'50',
#                                            u'dfp_height_4': u'280',
#                                            u'dfp_width': u'300',
#                                            u'dfp_width_2': u'320',
#                                            u'dfp_width_3': u'300',
#                                            u'dfp_width_4': u'336'}},
#                u'centerTop_13': {u'description': u'This is a latest article by specified root category ordered by published_at desc',
#                                  u'name': u'subject/latest/articles',
#                                  u'vars': {u'count': u'2',
#                                            u'image_param_string': u'w_300,h_250,c_fill,g_face:center,q_60,f_jpg',
#                                            u'show_heading': u'no'}},
#                u'centerTop_14': {u'description': u'this module is used to set up the dfp slots on the page',
#                                  u'instance': u'ad text-align-center adx no-vis-30 labeled_ad sweetart2',
#                                  u'name': u'ads/dfpslot',
#                                  u'vars': {u'dfp_ad_unit': u'/51859126/parent_m_ar/gut_890_4',
#                                            u'dfp_div_id': u'300x250_4',
#                                            u'dfp_height': u'250',
#                                            u'dfp_height_2': u'50',
#                                            u'dfp_height_3': u'50',
#                                            u'dfp_height_4': u'280',
#                                            u'dfp_width': u'300',
#                                            u'dfp_width_2': u'320',
#                                            u'dfp_width_3': u'300',
#                                            u'dfp_width_4': u'336'}},
#                u'centerTop_15': {u'description': u'This is a latest article by specified root category ordered by published_at desc',
#                                  u'name': u'subject/latest/articles',
#                                  u'vars': {u'count': u'2',
#                                            u'image_param_string': u'w_300,h_250,c_fill,g_face:center,q_60,f_jpg',
#                                            u'show_heading': u'no'}},
#                u'centerTop_16': {u'description': u'Ads Rubicon slot for use outside of DFP delivery',
#                                  u'instance': u'ad text-align-center adx no-vis-30 ad_with_label ad300_250 sweetart2',
#                                  u'name': u'ads/rubicon',
#                                  u'vars': {u'ad_slot_name': u'Answers_com_MWeb_RFM_300x250_2_ROS',
#                                            u'height': u'250',
#                                            u'iframe_class': u'rubicon_300x250_1',
#                                            u'rp_kw': u'gut_890_5',
#                                            u'width': u'300'}},
#                u'centerTop_17': {u'description': u'This is a latest article by specified root category ordered by published_at desc',
#                                  u'name': u'subject/latest/articles',
#                                  u'vars': {u'count': u'2',
#                                            u'image_param_string': u'w_300,h_250,c_fill,g_face:center,q_60,f_jpg',
#                                            u'show_heading': u'no'}},
#                u'centerTop_2': {u'name': u'carousel/ui/img'},
#                u'centerTop_3': {u'name': u'carousel/ui/subtitle'},
#                u'centerTop_4': {u'name': u'carousel/ui/text'},
#                u'centerTop_5': {u'description': u'this module is used to set up the dfp slots on the page',
#                                 u'instance': u'ad text-align-center adx no-vis-10 before_nav labeled_ad sweetart near_nav',
#                                 u'name': u'ads/dfpslot',
#                                 u'vars': {u'dfp_ad_unit': u'/51859126/parent_m_ar/gut_890_2',
#                                           u'dfp_div_id': u'300x250_2',
#                                           u'dfp_height': u'250',
#                                           u'dfp_height_2': u'50',
#                                           u'dfp_height_3': u'50',
#                                           u'dfp_height_4': u'280',
#                                           u'dfp_width': u'300',
#                                           u'dfp_width_2': u'320',
#                                           u'dfp_width_3': u'300',
#                                           u'dfp_width_4': u'336'}},
#                u'centerTop_6': {u'description': u'Display an open or close div tag, used to wrap modules in a div',
#                                 u'instance': u'carousel_slideshow_buttons clearfix',
#                                 u'name': u'utility/wrapper',
#                                 u'vars': {u'class': u'', u'id': u''}},
#                u'centerTop_7': {u'description': u'flight componenet for navigating backwards through a carousel',
#                                 u'name': u'carousel/ui/buttons/previous',
#                                 u'vars': {u'button_text': u'PREV'}},
#                u'centerTop_8': {u'name': u'carousel/ui/buttons/next'},
#                u'centerTop_9': {u'description': u'Display an open or close div tag, used to wrap modules in a div',
#                                 u'instance': u'close',
#                                 u'name': u'utility/wrapper',
#                                 u'vars': {u'class': u'',
#                                           u'id': u'',
#                                           u'type': u'close'}},
#                u'footer_0': {u'description': u'Simply places a block on the page with whatever HTML (or css and javascript) is configured. Tokens available: {CURRENT_URL}',
#                              u'instance': u'fban fban_interstitial',
#                              u'name': u'html',
#                              u'vars': {u'location': u'feet',
#                                        u'payload': u'<script>\nvar fban_interstitial_config = {\n    \'placementid\': \'168416999909992_974456065972744\',\n\n    \'trigger_on_timer\': false,\n    \'timer_seconds\': null,\n\n    \'trigger_on_slide_change\': true,\n    \'slide_count_start\': 5,\n    \'slide_count_repeat_interval\': 5\n};\n</script>\n<style>\n.module.fban_interstitial {\n  display: block;\n  background: white;\n  height: 0;\n  width: 0;\n  position: absolute;\n  overflow: hidden;\n  z-index: -999;\n  opacity: 0;\n  margin: 0;\n  padding: 0;\n  border: none;\n}\n.module.fban_interstitial.adloaded {\n  height: 100%;\n  width: 100%;\n  height: -webkit-calc(100vh);\n  width: -webkit-calc(100vw);\n  height: calc(100vh);\n  width: calc(100vw);\n  position: fixed;\n  top: 0;\n  right: 0;\n  bottom: 0;\n  left: 0;\n  z-index: 999;\n  opacity: 1;\n  display: none;\n}\n.isMobileSafari .module.fban_interstitial.adloaded {\n  height: 100%;\n  width: 100%;\n}\n.module.fban_interstitial .fb_iframe_widget {\n  position: absolute;\n  top: -30px;\n}\n.fban_interstitial .fban_interstitial_close {\n  position: absolute;\n  top: 5px;\n  right: 5px;\n  padding: 5px;\n  text-align: center;\n  cursor: pointer;\n}\n.fban_interstitial .fban_interstitial_close span {\n  font-family: Arial, sans-serif;\n  font-size: 40px;\n  font-weight: normal;\n  background: rgba(0,0,0, 0.33);\n  box-shadow: 0 0 3px rgba(255,255,255, 0.2);\n  color: #eee;\n  border-radius: 50px;\n  display: block;\n  width: 50px;\n  height: 50px;\n  line-height: 50px;\n  overflow: hidden;\n}\n.fban_interstitial .fbAdLink {\n  display: block;\n  height: 100%;\n  width: 100%;\n}\n.fban_interstitial .fbAdMedia {\n  background: center center no-repeat;\n  background-size: cover;\n  -webkit-animation: paninterstitial 10s infinite;\n  -webkit-animation-timing-function: ease-in-out;\n  animation: paninterstitial 10s infinite;\n  animation-timing-function: ease-in-out;\n  position: relative;\n  padding: 0 0 75% 0; /* 4:3 */\n  height: 0;\n  box-shadow: inset 0 0px 35px rgba(0,0,0,.2);\n}\n.fban_interstitial .fban_interstitial_top {\n  position: relative;\n}\n.fban_interstitial .fban_interstitial_top .fbAdIcon {\n  text-align: center;\n  position: absolute;\n  bottom: -35px;\n  width: 100%;\n}\n.fban_interstitial .fbAdIcon img {\n  width: 60px !important;\n  height: 60px !important;\n  margin: auto;\n  box-shadow: 0 3px 8px rgba(0,0,0,.3);\n  -webkit-box-sizing: content-box;\n  box-sizing: content-box;\n  border: 1px solid #333;\n  outline: 3px solid #fff;\n}\n.fban_interstitial .fban_interstitial_body {\n    color: #666;\n    font-size: 13px;\n    padding: 40px 20px 0;\n    text-align: center;\n}\n.fban_interstitial .fbAdTitle {\n    color: #333;\n    font-size: 18px;\n    font-weight: bold;\n    padding: 10px 0 15px;\n    letter-spacing: -.05em;\n    line-height: 1.5em;\n}\n.fban_interstitial .fbAdSubtitle {\n    display: none;\n    color: #999;\n    margin-top: -10px;\n    margin-bottom: 10px;\n    letter-spacing: .04em;\n}\n.fban_interstitial .fbAdSocialContext {\n    color: #999;\n    margin-top: -10px;\n    margin-bottom: 10px;\n    letter-spacing: .04em;\n    text-decoration: underline;\n}\n.fban_interstitial .fbAdBody {\n    font-size: 16px;\n    line-height: 1.5em;\n    padding: 15px 0;\n}\n.fban_interstitial .fbAdCallToActionWrapper {\n    background: rgba(255,255,255,.8);\n    position: absolute;\n    bottom: 0;\n    width: 100%;\n    padding: 20px 10px 25px;\n    text-align: center;\n    box-shadow: 0 0 30px rgba(0,0,0,0.1);\n}\n.fban_interstitial .fbAdCallToActionWrapper .fbAdIcon {\n    display: none;\n}\n.fban_interstitial .fbAdCallToAction {\n    position: relative;\n    color: #ffffff;\n    text-decoration: none;\n    font-family: \'Oswald\', \'Helvetica Neue\', \'Open Sans\', \'Arial\';\n    display: block;\n    border-radius: 6px;\n    text-align: center;\n    -webkit-transform: translate(0, 0);\n    -moz-transform: translate(0, 0);\n    transform: translate(0, ...
#                u'footer_1': {u'description': u'Simply places a block on the page with whatever HTML (or css and javascript) is configured. Tokens available: {CURRENT_URL}',
#                              u'instance': u'image_checker',
#                              u'name': u'html',
#                              u'vars': {u'payload': u'<script>\ndocument.addEventListener("DOMContentLoaded", function(event) {\n  var firstSection = document.querySelector(\'.subject_section:not(.intro_only)\'),\n      hasQuiz = (document.querySelector(\'.intro_only .pb_feed\') !== null) ? true : false,\n      kids, n=0, node;\n\n  if (hasQuiz === false && firstSection !== null) {\n    kids = Array.prototype.slice.apply(firstSection.childNodes);\n\n    for (;n<kids.length;n++) {\n      node = kids[n]\n      if (/no_image/.test(node.className)) {\n          var subjectImage = document.querySelector(\'.subject_image\');\n          subjectImage.className = subjectImage.className.replace(/hide/g, \'\');\n          break;\n      }\n    }\n  }\n});\n</script>'}},
#                u'footer_2': {u'description': u'Simply places a block on the page with whatever HTML (or css and javascript) is configured. Tokens available: {CURRENT_URL}',
#                              u'instance': u'random_color',
#                              u'name': u'html',
#                              u'vars': {u'payload': u"<script>\n\tvar colorObj = {\n\t\tred: '#f44848',\n\t\torange: '#ffb983',\n\t\tpink: '#ffa159',\n\t\tpurple: '#9e9ed8',\n\t\tyellow: '#fee24a',\n\t\tgreen: '#66c768'\n\t};\n\n\tvar colorName = [\n\t\t\t'red',\n\t\t\t'orange',\n\t\t\t'pink',\n\t\t\t'purple',\n\t\t\t'yellow',\n\t\t\t'green'\n\t\t];\n\n\tfunction getColor (ch) {\n\t\tvar ch = ch || 'a';\n\t\treturn (ch.charCodeAt() % (colorName.length));\n\t}\n\n\tvar color = colorName[getColor(location.pathname.split(/\\//).splice(-1)[0][0])];\n\n\tdocument.body.className += ' ' + color;\n</script>"}},
#                u'footer_3': {u'description': u'Simply places a block on the page with whatever HTML (or css and javascript) is configured. Tokens available: {CURRENT_URL}',
#                              u'instance': u'ad_checker',
#                              u'name': u'html',
#                              u'vars': {u'payload': u"    <script>\n    var adx = Array.prototype.slice.apply(document.querySelectorAll('.adx')),\n    invalid = [],\n    valid = [];\n\n    adx.forEach(function (node) {\n        var prevNode;\n\n        if (/no-vis/.test(node.className)) {\n            prevNode = node.previousElementSibling;\n\n            //console.info(node);\n\n            //console.info('Is prevNode a module? :: %s', (/module/.test(prevNode.className) == true));\n            //console.info('Is prevNode empty? :: %s', (prevNode.innerHTML.replace(/\\s/g, '').length === 0));\n            //console.info('Is prevNode supposed to be hidden? :: %s', (/hide/.test(prevNode.className) === true));\n            //console.info('Is prevNode an ad? :: %s', (/ad/.test(prevNode.className) === true));\n\n            if (((/module/.test(prevNode.className) === true) && ((/ad/.test(prevNode.className) === true) || (prevNode.innerHTML.replace(/\\s/g, '').length === 0) || (/hide/.test(prevNode.className) === true)))) {\n                //console.info('Pushing to invalid');\n                invalid.push(node);\n            } else {\n                //console.info('Pushing to valid');\n                valid.push(node);\n            }\n            //console.info('----');\n        }\n    });\n\n    $(function () {\n        valid.forEach(function (node, idx) {\n            if (idx > 1) {\n                return $(node).trigger('addContent');\n            }\n\n            if (/no-vis/.test(node.className)) {\n                return $(node).trigger('build');\n            }\n        });\n    });\n    </script>"}},
#                u'footer_4': {u'description': u'Refresh dfp and third-party ads',
#                              u'name': u'ads/refresher',
#                              u'vars': {u'amazon_page_depth_refresh_start': u'0',
#                                        u'dfp_refresh_interval': u'7000',
#                                        u'dfp_timer_refresh_interval': u'1500',
#                                        u'max_dfp_consecutive_timed': u'2',
#                                        u'max_third_party_consecutive_timed': u'10',
#                                        u'pre_ping': u'off',
#                                        u'refresh_counter_custom_variable': u'guteref',
#                                        u'refresh_event_list': u'carousel_slide_change',
#                                        u'refresh_on_every_nth_click': u'1',
#                                        u'reload_amz_bid': u'off',
#                                        u'reload_cas_bid': u'off',
#                                        u'reload_openx_bid': u'off',
#                                        u'reload_pub_bid': u'off',
#                                        u'third_party_refresh_interval': u'7000',
#                                        u'timed_refresh_counter_custom_variable': u'gutetimedref',
#                                        u'use_dfp_timed_refresh': u'off',
#                                        u'use_third_party_timed_refresh': u'off'}},
#                u'footer_5': {u'name': u'subject/mobile/vslide'},
#                u'footer_6': {u'instance': u'',
#                              u'name': u'tracking/adsnippet',
#                              u'vars': {u'click_tracking': u'On Click'}},
#                u'footer_7': {u'name': u'tracking/pagebottom',
#                              u'vars': {u'comscore': u'yes',
#                                        u'quantcast': u'yes'}},
#                u'header_0': {u'description': u'Simply places a block on the page with whatever HTML (or css and javascript) is configured. Tokens available: {CURRENT_URL}',
#                              u'instance': u'fb-js-sdk-audience-network',
#                              u'name': u'html',
#                              u'vars': {u'location': u'head',
#                                        u'payload': u'<script src="//www.facebook.com/assets.php/en_US/sdk/xfbml.ad.js?#version=v2.5&appId=168416999909992"></script>\n<script>\nfb_graph_version = \'v2.5\';\nFB.init({\n  appId          : fb_app_id,\n  channelUrl : \'channel.html\',\n  status         : true,\n  cookie        : true, \n  xfbml          : true,\n  version       : fb_graph_version\n});\n\n(function(){\n    // FBAN REFRESH\n    var setup_listeners = true;\n    window.fban_refresh = function(){\n        var $fbad_els;\n        if(setup_listeners){\n            setup_listeners = false;\n            FB.Event.subscribe(\n                \'ad.loaded\',\n                function(errorCode, errorMessage) {\n                    $(\'.fban_refresh, .fban-refresh\').find(document.getElementsByTagName(\'fb:ad\')).closest(\'.module\').show();\n                }\n            );\n            FB.Event.subscribe(\n                \'ad.error\',\n                function(errorCode, errorMessage) {\n                    $(\'.fban_refresh, .fban-refresh\').find(document.getElementsByTagName(\'fb:ad\')).closest(\'.module\').hide();\n                }\n            );\n        }\n        $fbad_els = $(\'.fban_refresh, .fban-refresh\').find(document.getElementsByTagName(\'fb:ad\'));\n        $fbad_els\n            .removeAttr(\'fb-xfbml-state\')\n            .removeAttr(\'fb-iframe-plugin-query\')\n            .removeAttr(\'fb-xfbml-state\');\n        FB.XFBML.parse();\n    };\n    $([document,document.body]).on("carousel_slide_change fban_refresh", fban_refresh);\n})();\n</script>'}},
#                u'header_1': {u'description': u'Module used to set up DFP',
#                              u'name': u'ads/dfpheader2',
#                              u'vars': {u'iframe_sandbox': u'on',
#                                        u'openx_bidder': u'yes'}},
#                u'header_2': {u'description': u'Simply places a block on the page with whatever HTML (or css and javascript) is configured. Tokens available: {CURRENT_URL}',
#                              u'instance': u'temp_header',
#                              u'name': u'html',
#                              u'vars': {u'payload': u'<style>\n\t/** HEADER STYLES **/\n\t.header_mobile_gute {\n\t\tposition: relative;\n\t\theight: 49px;\n\t\tbackground-color: #136ad5;\n\t\tbox-shadow: 0 0px 4px 0px rgba(19, 19, 19, .5);\n\t}\n\t.header_mobile_gute .logo {\n\t\tposition: relative;\n\t\tpadding-left: 10px;\n\t\tpadding-right: 115px;\n\t}\n\t.header_mobile_gute .format_toggle {\n\t\tposition: absolute;\n\t\tright: 5px;\n\t\twidth: 102px;\n\t}\n\n\t.header_mobile_gute .format_toggle.thin {\n\t\twidth: 68px;\n\t}\n\n\t.header_mobile_gute .logo,\n\t.header_mobile_gute .format_toggle {\n\t\ttop: 50%;\n\t\t-webkit-transform: translate(0, -50%);\n\t\t-moz-transform: translate(0, -50%);\n\t\t-ms-transform: translate(0, -50%);\n\t\t-o-transform: translate(0, -50%);\n\t\ttransform: translate(0, -50%);\n\t}\n\n\n\t/** FORMAT TOGGLE STYLES **/\n\t.format_toggle .option {\n\t\tdisplay: block;\n\t\tfloat: left;\n\t\tpadding: 8px 6px;\n\t\tbackground-color: #1E78D7;\n\t\tborder: 1px solid #0854cf;\n\t\ttext-align: center;\n\t\tfont-size: .75em;\n\t\ttext-decoration: none;\n\t\tcolor: #fff;\n\n\t\t-webkit-transition: border-color 50ms;\n\t\t-moz-transition: border-color 50ms;\n\t\ttransition: border-color 50ms;\n\t}\n\t.format_toggle .option:hover {\n\t\tbackground-color: #d7d8d8;\n\t\tcolor: #fff;\n\t}\n\t.format_toggle .option:first-child {\n\t\tborder-radius: 3px 0 0 3px;\n\t}\n\t.format_toggle .option:nth-child(2) {\n\t\tborder-right-width: 0;\n\t\tborder-left-width: 0;\n\t}\n\t.format_toggle .option:last-child {\n\t\tborder-radius: 0 3px 3px 0;\n\t}\n\t.format_toggle .option.selected {\n\t\tbackground-color: #1562D2;\n\t\tborder-color: #0854cf;\n\t\tcolor: #fff;\n\t}\n\t.format_toggle .option.disabled {\n\t\tpointer-events: none;\n\t\tcursor: default;\n\t}\n\t.format_toggle .option.disabled:hover {\n\t\tcolor: #c3c4c5 !important;\n\t}\n\n\t.format_toggle .option .fa {\n\t\tposition: relative;\n\t\ttop: -1px;\n\t}\n</style>\n\n<header class="header_mobile_gute clearfix">\n\t<figure class="logo">\n\t\t<a track="home_tools/PAGE" title="Answers.com home" href="http://www.answers.com">\n\t\t\t<svg width="115" height="30">\n\t\t\t\t<image xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="//rxs1.answcdn.com/includes/images/redcarpet/answers-logo-white.svg" width="115" height="30" src="//rxs1.answcdn.com/includes/images/onboarding/answers-logo-white.png">\n\t\t\t</svg>\n\t\t</a>\n\t</figure>\n</header>\n\n\n\n<script>\n\t(function() {\n\n\t\tvar getLmi = function() {\n\t\t\treturn decodeURIComponent(document.cookie.replace(new RegExp("(?:(?:^|.*;)\\\\s*" + encodeURIComponent(\'mode_id\').replace(/[\\-\\.\\+\\*]/g, "\\\\$&") + "\\\\s*\\\\=\\\\s*([^;]*).*$)|^.*$"), "$1")) || null;\n\t\t};\n\n\t\tvar getPostId = function() {\n\t\t\tvar id = location.pathname.split(\'/\')[2];\n\n\t\t\tif (isNaN(id) === true) {\n\t\t\t\tid = $(\'.current_batch\').data(\'batch-id\') || 0;\n\t\t\t}\n\n\t\t\treturn id;\n\t\t};\n\n\t\tvar check_videos = function () {\n\t\t\t$(function () {\n\t\t\t\tvar url =  \'//\' + location.host + \'/endpoint/guides/posts/sections\',\n\t\t\t\t\tid = getPostId();\n\n\t\t\t\t$.ajax({\n\t\t\t\t\turl: url,\n\t\t\t\t\ttype: \'GET\',\n\t\t\t\t\tdataType: \'json\',\n\t\t\t\t\tdata: {posts_id: id},\n\t\t\t\t\terror: function (one, two, three) {\n\t\t\t\t\t},\n\t\t\t\t\tsuccess: function (data) {\n\t\t\t\t\t\tif (data.error) {\n\t\t\t\t\t\t\t$(\'.format_toggle .option.video\').remove();\n\t\t\t\t\t\t\t$(\'.format_toggle\').addClass(\'thin\');\n\t\t\t\t\t\t\treturn false;\n\t\t\t\t\t\t}\n\n\t\t\t\t\t\tvar results = data.result,\n\t\t\t\t\t\t\tlen = results.length,\n\t\t\t\t\t\t\ti=0;\n\n\t\t\t\t\t\tfor (; i < len; i++) {\n\t\t\t\t\t\t\tvar d = results[i];\n\n\t\t\t\t\t\t\tif (d.type === \'video\') {\n\t\t\t\t\t\t\t\t$(\'.format_toggle .option.video\').removeClass(\'disabled\');\n\t\t\t\t\t\t\t\treturn true;\n\t\t\t\t\t\t\t}\n\t\t\t\t\t\t}\n\t\t\t\t\t}\n\t\t\t\t});\n\t\t\t});\n\t\t};\n\n\t\tvar initialize = function() {\n\ ...
#                u'header_3': {u'name': u'js/head/scripts/home'},
#                u'header_4': {u'name': u'js/login'},
#                u'header_5': {u'name': u'js/decoderedirect'},
#                u'header_6': {u'description': u'',
#                              u'name': u'tracking/googleanalytics',
#                              u'vars': {u'custom_variable_1': u'null_mod_override_ar_55825',
#                                        u'track_fb_status': u'off'}},
#                u'header_7': {u'name': u'js/metatags',
#                              u'vars': {u'keyword-title-suffix': u'',
#                                        u'page_type': u'gutenberg',
#                                        u'profile_title_suffix': u''}},
#                u'header_8': {u'description': u'Module for configuring a Gutenberg article slideshow and adapting data to presentation.',
#                              u'name': u'carousel/slideshow',
#                              u'vars': {u'chunk_on_punctuation': u'yes',
#                                        u'image_param_string': u'w_728,c_fill,g_face:center,q_60,f_jpg',
#                                        u'make_section_title_a_pane': u'no',
#                                        u'text_chunk_size': u'100'}},
#                u'header_9': {u'description': u'this module is used to set up the dfp slots on the page',
#                              u'instance': u'dfp_1x1',
#                              u'name': u'ads/dfpslot',
#                              u'vars': {u'dfp_ad_unit': u'/51859126/answ_mobile_1x1',
#                                        u'dfp_div_id': u'answ_mobile_1x1',
#                                        u'dfp_height': u'1',
#                                        u'dfp_width': u'1'}}},
#  u'selective_css': u'1',
#  u'skin': u'red-carpet',
#  u'theme': u'3-col-responsive'}

# %%
#Set constants

OpenX_ids = {"728": , "160": , "300": }
Casale_ids = {"728": , "160": , "300": }
# Out:
#   File "<ipython-input-4-c2f79816e45d>", line 3
#     OpenX_ids = {"728": , "160": , "300": }
#                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # functions

# %%
#Mobile Functions
'''Replaces ad units in '''
def replaceDFPUnits_Mobile(json, tag):
    #replaces all ad units with a given tag
    for module in json['partials']:
        name = json['partials'][module]['name']
        if name == 'ads/dfpslot' and json['partials'][module]['vars']['dfp_height'] != '1' :
            json['partials'][module]['vars']['dfp_ad_unit'] = "51859126/parent_m_ar/" + str(tag) + str(determineAdSlot(json['partials'][module]['vars']['dfp_ad_unit']))
        elif name == 'ads/rubicon':
            json['partials'][module]['vars']['rp_kw'] = str(tag) + "_5"
        elif name == 'ads/outbrain':
            json['partials'][module]['vars']['variant'] = str(tag) + "_1"
    return json

#Desktop Functions
def replaceDFPUnits_Desktop(json, tag, casale_ids, openx_ids):
    #replaces all ad units with a given tag
    for module in json['partials']:
        name = json['partials'][module]['name']
        ad_unit = json['partials'][module]['vars']
        varz = json['partials'][module]['vars']
        instance = json['partials'][module]['instance']
        #Replace DFP ad units
        if name == 'ads/dfpslot':
            ad_unit['dfp_ad_unit'] = "51859126/parent_ar/" + "child_ar_" + str(tag[-2:]) + "/" + str(tag) + "_" + str(determineAdSize(varz['dfp_width']))
        elif name == 'ads/outbrain':
            json['partials'][module]['vars']['variant'] = str(tag) + "_1"
            

#Helper functions            
def determineAdSlot(ad_unit):
    if ad_unit[-2:] == "_1":
        end = "_1"
        return end
    elif ad_unit[-2:] == "_2":
        end = "_2"
        return end
    elif ad_unit[-2:] == "_3":
        end = "_3"
        return end
    elif ad_unit[-2:] == "_4":
        end = "_4"
        return end
    
def determineAdSize(ad_unit):
    if ad_unit == '300':
        return "300x250"
    elif ad_unit == '728':
        return "728x90"
    elif ad_unit == '160':
        return "160x600"
    
def replaceDFP_Desktop(module):
    if module['name'] == 'ads/dfpslot':
        module['dfp_ad_unit'] = "51859126/parent_ar/" + "child_ar_" + str(tag[-2:]) + "/" + str(tag) + "_" + str(determineAdSize(varz['dfp_width']))
        
def replaceDFP_Mobile(module):
    if module['name'] == 'ads/dfpslot':
        module['dfp_ad_unit'] = "51859126/parent_m_ar/" + str(tag) + str(determineAdSlot(json['partials'][module]['vars']['dfp_ad_unit']))

def replaceOB(module):
    if module['name'] == 'ads/outbrain':
        module['vars']['variant'] = str(tag) + "_1"

def replaceCasale(module, casale_id):
    if module['name'] == 'links/casale':
        module['vars']['casale_id'] = casale_id
        
def replaceOpenX(module, OpenX_ids):
    if module['name'] == 'links/openx':
        module['vars']['auid'] = str(tag) + "_1"
    
#QA Functions   
def QA_div_id():
     for module in json['partials']:
        if json['partials'][module]['name'] == 'ads/dfpslot':
            json['partials'][module]['vars'] = tag

# %%
#new_json = open('json_out','w')
json_data = replaceDFPUnits_Mobile(json_dict,"gut_811")
pprint(json_data)

with open('outfile.json', 'w') as outfile:
    json.dump(json_data, outfile)
# Out:
# {u'ads': 1,
#  u'adsnip': {u'click_tracking': u'on'},
#  u'compactor': u'on',
#  u'custom': {},
#  u'partials': {u'centerTop_0': {u'description': u'this module is used to set up the dfp slots on the page',
#                                 u'instance': u'ad text-align-center labeled_ad',
#                                 u'name': u'ads/dfpslot',
#                                 u'vars': {u'dfp_ad_unit': '51859126/parent_m_ar/gut_811_1',
#                                           u'dfp_div_id': u'300x250_1',
#                                           u'dfp_height': u'250',
#                                           u'dfp_height_2': u'50',
#                                           u'dfp_height_3': u'50',
#                                           u'dfp_width': u'300',
#                                           u'dfp_width_2': u'320',
#                                           u'dfp_width_3': u'300'}},
#                u'centerTop_1': {u'name': u'carousel/ui/title'},
#                u'centerTop_10': {u'description': u'Adds skin-specific Outbrain tags',
#                                  u'name': u'ads/outbrain',
#                                  u'vars': {u'variant': 'gut_811_1',
#                                            u'widget': u'MB_2'}},
#                u'centerTop_11': {u'description': u'This is a latest article by specified root category ordered by published_at desc',
#                                  u'name': u'subject/latest/articles',
#                                  u'vars': {u'count': u'2',
#                                            u'heading': u'Latest Articles',
#                                            u'image_param_string': u'w_300,h_250,c_fill,g_face:center,q_60,f_jpg'}},
#                u'centerTop_12': {u'description': u'this module is used to set up the dfp slots on the page',
#                                  u'instance': u'ad text-align-center adx no-vis-30 labeled_ad sweetart2',
#                                  u'name': u'ads/dfpslot',
#                                  u'vars': {u'dfp_ad_unit': '51859126/parent_m_ar/gut_811_3',
#                                            u'dfp_div_id': u'300x250_3',
#                                            u'dfp_height': u'250',
#                                            u'dfp_height_2': u'50',
#                                            u'dfp_height_3': u'50',
#                                            u'dfp_height_4': u'280',
#                                            u'dfp_width': u'300',
#                                            u'dfp_width_2': u'320',
#                                            u'dfp_width_3': u'300',
#                                            u'dfp_width_4': u'336'}},
#                u'centerTop_13': {u'description': u'This is a latest article by specified root category ordered by published_at desc',
#                                  u'name': u'subject/latest/articles',
#                                  u'vars': {u'count': u'2',
#                                            u'image_param_string': u'w_300,h_250,c_fill,g_face:center,q_60,f_jpg',
#                                            u'show_heading': u'no'}},
#                u'centerTop_14': {u'description': u'this module is used to set up the dfp slots on the page',
#                                  u'instance': u'ad text-align-center adx no-vis-30 labeled_ad sweetart2',
#                                  u'name': u'ads/dfpslot',
#                                  u'vars': {u'dfp_ad_unit': '51859126/parent_m_ar/gut_811_4',
#                                            u'dfp_div_id': u'300x250_4',
#                                            u'dfp_height': u'250',
#                                            u'dfp_height_2': u'50',
#                                            u'dfp_height_3': u'50',
#                                            u'dfp_height_4': u'280',
#                                            u'dfp_width': u'300',
#                                            u'dfp_width_2': u'320',
#                                            u'dfp_width_3': u'300',
#                                            u'dfp_width_4': u'336'}},
#                u'centerTop_15': {u'description': u'This is a latest article by specified root category ordered by published_at desc',
#                                  u'name': u'subject/latest/articles',
#                                  u'vars': {u'count': u'2',
#                                            u'image_param_string': u'w_300,h_250,c_fill,g_face:center,q_60,f_jpg',
#                                            u'show_heading': u'no'}},
#                u'centerTop_16': {u'description': u'Ads Rubicon slot for use outside of DFP delivery',
#                                  u'instance': u'ad text-align-center adx no-vis-30 ad_with_label ad300_250 sweetart2',
#                                  u'name': u'ads/rubicon',
#                                  u'vars': {u'ad_slot_name': u'Answers_com_MWeb_RFM_300x250_2_ROS',
#                                            u'height': u'250',
#                                            u'iframe_class': u'rubicon_300x250_1',
#                                            u'rp_kw': 'gut_811_5',
#                                            u'width': u'300'}},
#                u'centerTop_17': {u'description': u'This is a latest article by specified root category ordered by published_at desc',
#                                  u'name': u'subject/latest/articles',
#                                  u'vars': {u'count': u'2',
#                                            u'image_param_string': u'w_300,h_250,c_fill,g_face:center,q_60,f_jpg',
#                                            u'show_heading': u'no'}},
#                u'centerTop_2': {u'name': u'carousel/ui/img'},
#                u'centerTop_3': {u'name': u'carousel/ui/subtitle'},
#                u'centerTop_4': {u'name': u'carousel/ui/text'},
#                u'centerTop_5': {u'description': u'this module is used to set up the dfp slots on the page',
#                                 u'instance': u'ad text-align-center adx no-vis-10 before_nav labeled_ad sweetart near_nav',
#                                 u'name': u'ads/dfpslot',
#                                 u'vars': {u'dfp_ad_unit': '51859126/parent_m_ar/gut_811_2',
#                                           u'dfp_div_id': u'300x250_2',
#                                           u'dfp_height': u'250',
#                                           u'dfp_height_2': u'50',
#                                           u'dfp_height_3': u'50',
#                                           u'dfp_height_4': u'280',
#                                           u'dfp_width': u'300',
#                                           u'dfp_width_2': u'320',
#                                           u'dfp_width_3': u'300',
#                                           u'dfp_width_4': u'336'}},
#                u'centerTop_6': {u'description': u'Display an open or close div tag, used to wrap modules in a div',
#                                 u'instance': u'carousel_slideshow_buttons clearfix',
#                                 u'name': u'utility/wrapper',
#                                 u'vars': {u'class': u'', u'id': u''}},
#                u'centerTop_7': {u'description': u'flight componenet for navigating backwards through a carousel',
#                                 u'name': u'carousel/ui/buttons/previous',
#                                 u'vars': {u'button_text': u'PREV'}},
#                u'centerTop_8': {u'name': u'carousel/ui/buttons/next'},
#                u'centerTop_9': {u'description': u'Display an open or close div tag, used to wrap modules in a div',
#                                 u'instance': u'close',
#                                 u'name': u'utility/wrapper',
#                                 u'vars': {u'class': u'',
#                                           u'id': u'',
#                                           u'type': u'close'}},
#                u'footer_0': {u'description': u'Simply places a block on the page with whatever HTML (or css and javascript) is configured. Tokens available: {CURRENT_URL}',
#                              u'instance': u'fban fban_interstitial',
#                              u'name': u'html',
#                              u'vars': {u'location': u'feet',
#                                        u'payload': u'<script>\nvar fban_interstitial_config = {\n    \'placementid\': \'168416999909992_974456065972744\',\n\n    \'trigger_on_timer\': false,\n    \'timer_seconds\': null,\n\n    \'trigger_on_slide_change\': true,\n    \'slide_count_start\': 5,\n    \'slide_count_repeat_interval\': 5\n};\n</script>\n<style>\n.module.fban_interstitial {\n  display: block;\n  background: white;\n  height: 0;\n  width: 0;\n  position: absolute;\n  overflow: hidden;\n  z-index: -999;\n  opacity: 0;\n  margin: 0;\n  padding: 0;\n  border: none;\n}\n.module.fban_interstitial.adloaded {\n  height: 100%;\n  width: 100%;\n  height: -webkit-calc(100vh);\n  width: -webkit-calc(100vw);\n  height: calc(100vh);\n  width: calc(100vw);\n  position: fixed;\n  top: 0;\n  right: 0;\n  bottom: 0;\n  left: 0;\n  z-index: 999;\n  opacity: 1;\n  display: none;\n}\n.isMobileSafari .module.fban_interstitial.adloaded {\n  height: 100%;\n  width: 100%;\n}\n.module.fban_interstitial .fb_iframe_widget {\n  position: absolute;\n  top: -30px;\n}\n.fban_interstitial .fban_interstitial_close {\n  position: absolute;\n  top: 5px;\n  right: 5px;\n  padding: 5px;\n  text-align: center;\n  cursor: pointer;\n}\n.fban_interstitial .fban_interstitial_close span {\n  font-family: Arial, sans-serif;\n  font-size: 40px;\n  font-weight: normal;\n  background: rgba(0,0,0, 0.33);\n  box-shadow: 0 0 3px rgba(255,255,255, 0.2);\n  color: #eee;\n  border-radius: 50px;\n  display: block;\n  width: 50px;\n  height: 50px;\n  line-height: 50px;\n  overflow: hidden;\n}\n.fban_interstitial .fbAdLink {\n  display: block;\n  height: 100%;\n  width: 100%;\n}\n.fban_interstitial .fbAdMedia {\n  background: center center no-repeat;\n  background-size: cover;\n  -webkit-animation: paninterstitial 10s infinite;\n  -webkit-animation-timing-function: ease-in-out;\n  animation: paninterstitial 10s infinite;\n  animation-timing-function: ease-in-out;\n  position: relative;\n  padding: 0 0 75% 0; /* 4:3 */\n  height: 0;\n  box-shadow: inset 0 0px 35px rgba(0,0,0,.2);\n}\n.fban_interstitial .fban_interstitial_top {\n  position: relative;\n}\n.fban_interstitial .fban_interstitial_top .fbAdIcon {\n  text-align: center;\n  position: absolute;\n  bottom: -35px;\n  width: 100%;\n}\n.fban_interstitial .fbAdIcon img {\n  width: 60px !important;\n  height: 60px !important;\n  margin: auto;\n  box-shadow: 0 3px 8px rgba(0,0,0,.3);\n  -webkit-box-sizing: content-box;\n  box-sizing: content-box;\n  border: 1px solid #333;\n  outline: 3px solid #fff;\n}\n.fban_interstitial .fban_interstitial_body {\n    color: #666;\n    font-size: 13px;\n    padding: 40px 20px 0;\n    text-align: center;\n}\n.fban_interstitial .fbAdTitle {\n    color: #333;\n    font-size: 18px;\n    font-weight: bold;\n    padding: 10px 0 15px;\n    letter-spacing: -.05em;\n    line-height: 1.5em;\n}\n.fban_interstitial .fbAdSubtitle {\n    display: none;\n    color: #999;\n    margin-top: -10px;\n    margin-bottom: 10px;\n    letter-spacing: .04em;\n}\n.fban_interstitial .fbAdSocialContext {\n    color: #999;\n    margin-top: -10px;\n    margin-bottom: 10px;\n    letter-spacing: .04em;\n    text-decoration: underline;\n}\n.fban_interstitial .fbAdBody {\n    font-size: 16px;\n    line-height: 1.5em;\n    padding: 15px 0;\n}\n.fban_interstitial .fbAdCallToActionWrapper {\n    background: rgba(255,255,255,.8);\n    position: absolute;\n    bottom: 0;\n    width: 100%;\n    padding: 20px 10px 25px;\n    text-align: center;\n    box-shadow: 0 0 30px rgba(0,0,0,0.1);\n}\n.fban_interstitial .fbAdCallToActionWrapper .fbAdIcon {\n    display: none;\n}\n.fban_interstitial .fbAdCallToAction {\n    position: relative;\n    color: #ffffff;\n    text-decoration: none;\n    font-family: \'Oswald\', \'Helvetica Neue\', \'Open Sans\', \'Arial\';\n    display: block;\n    border-radius: 6px;\n    text-align: center;\n    -webkit-transform: translate(0, 0);\n    -moz-transform: translate(0, 0);\n    transform: translate(0, ...
#                u'footer_1': {u'description': u'Simply places a block on the page with whatever HTML (or css and javascript) is configured. Tokens available: {CURRENT_URL}',
#                              u'instance': u'image_checker',
#                              u'name': u'html',
#                              u'vars': {u'payload': u'<script>\ndocument.addEventListener("DOMContentLoaded", function(event) {\n  var firstSection = document.querySelector(\'.subject_section:not(.intro_only)\'),\n      hasQuiz = (document.querySelector(\'.intro_only .pb_feed\') !== null) ? true : false,\n      kids, n=0, node;\n\n  if (hasQuiz === false && firstSection !== null) {\n    kids = Array.prototype.slice.apply(firstSection.childNodes);\n\n    for (;n<kids.length;n++) {\n      node = kids[n]\n      if (/no_image/.test(node.className)) {\n          var subjectImage = document.querySelector(\'.subject_image\');\n          subjectImage.className = subjectImage.className.replace(/hide/g, \'\');\n          break;\n      }\n    }\n  }\n});\n</script>'}},
#                u'footer_2': {u'description': u'Simply places a block on the page with whatever HTML (or css and javascript) is configured. Tokens available: {CURRENT_URL}',
#                              u'instance': u'random_color',
#                              u'name': u'html',
#                              u'vars': {u'payload': u"<script>\n\tvar colorObj = {\n\t\tred: '#f44848',\n\t\torange: '#ffb983',\n\t\tpink: '#ffa159',\n\t\tpurple: '#9e9ed8',\n\t\tyellow: '#fee24a',\n\t\tgreen: '#66c768'\n\t};\n\n\tvar colorName = [\n\t\t\t'red',\n\t\t\t'orange',\n\t\t\t'pink',\n\t\t\t'purple',\n\t\t\t'yellow',\n\t\t\t'green'\n\t\t];\n\n\tfunction getColor (ch) {\n\t\tvar ch = ch || 'a';\n\t\treturn (ch.charCodeAt() % (colorName.length));\n\t}\n\n\tvar color = colorName[getColor(location.pathname.split(/\\//).splice(-1)[0][0])];\n\n\tdocument.body.className += ' ' + color;\n</script>"}},
#                u'footer_3': {u'description': u'Simply places a block on the page with whatever HTML (or css and javascript) is configured. Tokens available: {CURRENT_URL}',
#                              u'instance': u'ad_checker',
#                              u'name': u'html',
#                              u'vars': {u'payload': u"    <script>\n    var adx = Array.prototype.slice.apply(document.querySelectorAll('.adx')),\n    invalid = [],\n    valid = [];\n\n    adx.forEach(function (node) {\n        var prevNode;\n\n        if (/no-vis/.test(node.className)) {\n            prevNode = node.previousElementSibling;\n\n            //console.info(node);\n\n            //console.info('Is prevNode a module? :: %s', (/module/.test(prevNode.className) == true));\n            //console.info('Is prevNode empty? :: %s', (prevNode.innerHTML.replace(/\\s/g, '').length === 0));\n            //console.info('Is prevNode supposed to be hidden? :: %s', (/hide/.test(prevNode.className) === true));\n            //console.info('Is prevNode an ad? :: %s', (/ad/.test(prevNode.className) === true));\n\n            if (((/module/.test(prevNode.className) === true) && ((/ad/.test(prevNode.className) === true) || (prevNode.innerHTML.replace(/\\s/g, '').length === 0) || (/hide/.test(prevNode.className) === true)))) {\n                //console.info('Pushing to invalid');\n                invalid.push(node);\n            } else {\n                //console.info('Pushing to valid');\n                valid.push(node);\n            }\n            //console.info('----');\n        }\n    });\n\n    $(function () {\n        valid.forEach(function (node, idx) {\n            if (idx > 1) {\n                return $(node).trigger('addContent');\n            }\n\n            if (/no-vis/.test(node.className)) {\n                return $(node).trigger('build');\n            }\n        });\n    });\n    </script>"}},
#                u'footer_4': {u'description': u'Refresh dfp and third-party ads',
#                              u'name': u'ads/refresher',
#                              u'vars': {u'amazon_page_depth_refresh_start': u'0',
#                                        u'dfp_refresh_interval': u'7000',
#                                        u'dfp_timer_refresh_interval': u'1500',
#                                        u'max_dfp_consecutive_timed': u'2',
#                                        u'max_third_party_consecutive_timed': u'10',
#                                        u'pre_ping': u'off',
#                                        u'refresh_counter_custom_variable': u'guteref',
#                                        u'refresh_event_list': u'carousel_slide_change',
#                                        u'refresh_on_every_nth_click': u'1',
#                                        u'reload_amz_bid': u'off',
#                                        u'reload_cas_bid': u'off',
#                                        u'reload_openx_bid': u'off',
#                                        u'reload_pub_bid': u'off',
#                                        u'third_party_refresh_interval': u'7000',
#                                        u'timed_refresh_counter_custom_variable': u'gutetimedref',
#                                        u'use_dfp_timed_refresh': u'off',
#                                        u'use_third_party_timed_refresh': u'off'}},
#                u'footer_5': {u'name': u'subject/mobile/vslide'},
#                u'footer_6': {u'instance': u'',
#                              u'name': u'tracking/adsnippet',
#                              u'vars': {u'click_tracking': u'On Click'}},
#                u'footer_7': {u'name': u'tracking/pagebottom',
#                              u'vars': {u'comscore': u'yes',
#                                        u'quantcast': u'yes'}},
#                u'header_0': {u'description': u'Simply places a block on the page with whatever HTML (or css and javascript) is configured. Tokens available: {CURRENT_URL}',
#                              u'instance': u'fb-js-sdk-audience-network',
#                              u'name': u'html',
#                              u'vars': {u'location': u'head',
#                                        u'payload': u'<script src="//www.facebook.com/assets.php/en_US/sdk/xfbml.ad.js?#version=v2.5&appId=168416999909992"></script>\n<script>\nfb_graph_version = \'v2.5\';\nFB.init({\n  appId          : fb_app_id,\n  channelUrl : \'channel.html\',\n  status         : true,\n  cookie        : true, \n  xfbml          : true,\n  version       : fb_graph_version\n});\n\n(function(){\n    // FBAN REFRESH\n    var setup_listeners = true;\n    window.fban_refresh = function(){\n        var $fbad_els;\n        if(setup_listeners){\n            setup_listeners = false;\n            FB.Event.subscribe(\n                \'ad.loaded\',\n                function(errorCode, errorMessage) {\n                    $(\'.fban_refresh, .fban-refresh\').find(document.getElementsByTagName(\'fb:ad\')).closest(\'.module\').show();\n                }\n            );\n            FB.Event.subscribe(\n                \'ad.error\',\n                function(errorCode, errorMessage) {\n                    $(\'.fban_refresh, .fban-refresh\').find(document.getElementsByTagName(\'fb:ad\')).closest(\'.module\').hide();\n                }\n            );\n        }\n        $fbad_els = $(\'.fban_refresh, .fban-refresh\').find(document.getElementsByTagName(\'fb:ad\'));\n        $fbad_els\n            .removeAttr(\'fb-xfbml-state\')\n            .removeAttr(\'fb-iframe-plugin-query\')\n            .removeAttr(\'fb-xfbml-state\');\n        FB.XFBML.parse();\n    };\n    $([document,document.body]).on("carousel_slide_change fban_refresh", fban_refresh);\n})();\n</script>'}},
#                u'header_1': {u'description': u'Module used to set up DFP',
#                              u'name': u'ads/dfpheader2',
#                              u'vars': {u'iframe_sandbox': u'on',
#                                        u'openx_bidder': u'yes'}},
#                u'header_2': {u'description': u'Simply places a block on the page with whatever HTML (or css and javascript) is configured. Tokens available: {CURRENT_URL}',
#                              u'instance': u'temp_header',
#                              u'name': u'html',
#                              u'vars': {u'payload': u'<style>\n\t/** HEADER STYLES **/\n\t.header_mobile_gute {\n\t\tposition: relative;\n\t\theight: 49px;\n\t\tbackground-color: #136ad5;\n\t\tbox-shadow: 0 0px 4px 0px rgba(19, 19, 19, .5);\n\t}\n\t.header_mobile_gute .logo {\n\t\tposition: relative;\n\t\tpadding-left: 10px;\n\t\tpadding-right: 115px;\n\t}\n\t.header_mobile_gute .format_toggle {\n\t\tposition: absolute;\n\t\tright: 5px;\n\t\twidth: 102px;\n\t}\n\n\t.header_mobile_gute .format_toggle.thin {\n\t\twidth: 68px;\n\t}\n\n\t.header_mobile_gute .logo,\n\t.header_mobile_gute .format_toggle {\n\t\ttop: 50%;\n\t\t-webkit-transform: translate(0, -50%);\n\t\t-moz-transform: translate(0, -50%);\n\t\t-ms-transform: translate(0, -50%);\n\t\t-o-transform: translate(0, -50%);\n\t\ttransform: translate(0, -50%);\n\t}\n\n\n\t/** FORMAT TOGGLE STYLES **/\n\t.format_toggle .option {\n\t\tdisplay: block;\n\t\tfloat: left;\n\t\tpadding: 8px 6px;\n\t\tbackground-color: #1E78D7;\n\t\tborder: 1px solid #0854cf;\n\t\ttext-align: center;\n\t\tfont-size: .75em;\n\t\ttext-decoration: none;\n\t\tcolor: #fff;\n\n\t\t-webkit-transition: border-color 50ms;\n\t\t-moz-transition: border-color 50ms;\n\t\ttransition: border-color 50ms;\n\t}\n\t.format_toggle .option:hover {\n\t\tbackground-color: #d7d8d8;\n\t\tcolor: #fff;\n\t}\n\t.format_toggle .option:first-child {\n\t\tborder-radius: 3px 0 0 3px;\n\t}\n\t.format_toggle .option:nth-child(2) {\n\t\tborder-right-width: 0;\n\t\tborder-left-width: 0;\n\t}\n\t.format_toggle .option:last-child {\n\t\tborder-radius: 0 3px 3px 0;\n\t}\n\t.format_toggle .option.selected {\n\t\tbackground-color: #1562D2;\n\t\tborder-color: #0854cf;\n\t\tcolor: #fff;\n\t}\n\t.format_toggle .option.disabled {\n\t\tpointer-events: none;\n\t\tcursor: default;\n\t}\n\t.format_toggle .option.disabled:hover {\n\t\tcolor: #c3c4c5 !important;\n\t}\n\n\t.format_toggle .option .fa {\n\t\tposition: relative;\n\t\ttop: -1px;\n\t}\n</style>\n\n<header class="header_mobile_gute clearfix">\n\t<figure class="logo">\n\t\t<a track="home_tools/PAGE" title="Answers.com home" href="http://www.answers.com">\n\t\t\t<svg width="115" height="30">\n\t\t\t\t<image xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="//rxs1.answcdn.com/includes/images/redcarpet/answers-logo-white.svg" width="115" height="30" src="//rxs1.answcdn.com/includes/images/onboarding/answers-logo-white.png">\n\t\t\t</svg>\n\t\t</a>\n\t</figure>\n</header>\n\n\n\n<script>\n\t(function() {\n\n\t\tvar getLmi = function() {\n\t\t\treturn decodeURIComponent(document.cookie.replace(new RegExp("(?:(?:^|.*;)\\\\s*" + encodeURIComponent(\'mode_id\').replace(/[\\-\\.\\+\\*]/g, "\\\\$&") + "\\\\s*\\\\=\\\\s*([^;]*).*$)|^.*$"), "$1")) || null;\n\t\t};\n\n\t\tvar getPostId = function() {\n\t\t\tvar id = location.pathname.split(\'/\')[2];\n\n\t\t\tif (isNaN(id) === true) {\n\t\t\t\tid = $(\'.current_batch\').data(\'batch-id\') || 0;\n\t\t\t}\n\n\t\t\treturn id;\n\t\t};\n\n\t\tvar check_videos = function () {\n\t\t\t$(function () {\n\t\t\t\tvar url =  \'//\' + location.host + \'/endpoint/guides/posts/sections\',\n\t\t\t\t\tid = getPostId();\n\n\t\t\t\t$.ajax({\n\t\t\t\t\turl: url,\n\t\t\t\t\ttype: \'GET\',\n\t\t\t\t\tdataType: \'json\',\n\t\t\t\t\tdata: {posts_id: id},\n\t\t\t\t\terror: function (one, two, three) {\n\t\t\t\t\t},\n\t\t\t\t\tsuccess: function (data) {\n\t\t\t\t\t\tif (data.error) {\n\t\t\t\t\t\t\t$(\'.format_toggle .option.video\').remove();\n\t\t\t\t\t\t\t$(\'.format_toggle\').addClass(\'thin\');\n\t\t\t\t\t\t\treturn false;\n\t\t\t\t\t\t}\n\n\t\t\t\t\t\tvar results = data.result,\n\t\t\t\t\t\t\tlen = results.length,\n\t\t\t\t\t\t\ti=0;\n\n\t\t\t\t\t\tfor (; i < len; i++) {\n\t\t\t\t\t\t\tvar d = results[i];\n\n\t\t\t\t\t\t\tif (d.type === \'video\') {\n\t\t\t\t\t\t\t\t$(\'.format_toggle .option.video\').removeClass(\'disabled\');\n\t\t\t\t\t\t\t\treturn true;\n\t\t\t\t\t\t\t}\n\t\t\t\t\t\t}\n\t\t\t\t\t}\n\t\t\t\t});\n\t\t\t});\n\t\t};\n\n\t\tvar initialize = function() {\n\ ...
#                u'header_3': {u'name': u'js/head/scripts/home'},
#                u'header_4': {u'name': u'js/login'},
#                u'header_5': {u'name': u'js/decoderedirect'},
#                u'header_6': {u'description': u'',
#                              u'name': u'tracking/googleanalytics',
#                              u'vars': {u'custom_variable_1': u'null_mod_override_ar_55825',
#                                        u'track_fb_status': u'off'}},
#                u'header_7': {u'name': u'js/metatags',
#                              u'vars': {u'keyword-title-suffix': u'',
#                                        u'page_type': u'gutenberg',
#                                        u'profile_title_suffix': u''}},
#                u'header_8': {u'description': u'Module for configuring a Gutenberg article slideshow and adapting data to presentation.',
#                              u'name': u'carousel/slideshow',
#                              u'vars': {u'chunk_on_punctuation': u'yes',
#                                        u'image_param_string': u'w_728,c_fill,g_face:center,q_60,f_jpg',
#                                        u'make_section_title_a_pane': u'no',
#                                        u'text_chunk_size': u'100'}},
#                u'header_9': {u'description': u'this module is used to set up the dfp slots on the page',
#                              u'instance': u'dfp_1x1',
#                              u'name': u'ads/dfpslot',
#                              u'vars': {u'dfp_ad_unit': u'/51859126/answ_mobile_1x1',
#                                        u'dfp_div_id': u'answ_mobile_1x1',
#                                        u'dfp_height': u'1',
#                                        u'dfp_width': u'1'}}},
#  u'selective_css': u'1',
#  u'skin': u'red-carpet',
#  u'theme': u'3-col-responsive'}
