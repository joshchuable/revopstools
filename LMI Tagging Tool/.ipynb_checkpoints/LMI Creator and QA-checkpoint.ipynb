# %%
import json
import pandas as pd
import numpy as np
from pprint import pprint
import re

# %%
def json_parse(lmi_json):
    with open(lmi_json) as json_file:
         json_data = json.load(json_file)
    return json_data

json_dict = json_parse('infile.json')
pprint(json_dict)
# Out:
# {'ads': 1,
#  'adsnip': {'click_tracking': 'on'},
#  'compactor': 'on',
#  'custom': {},
#  'partials': {'centerTop_0': {'name': 'carousel/ui/title'},
#               'centerTop_1': {'name': 'carousel/ui/img'},
#               'centerTop_10': {'description': 'Adds skin-specific Outbrain '
#                                               'tags',
#                                'name': 'ads/outbrain',
#                                'vars': {'variant': 'gut_929_1',
#                                         'widget': 'MB_2'}},
#               'centerTop_11': {'description': 'This is a latest article by '
#                                               'specified root category ordered '
#                                               'by published_at desc',
#                                'name': 'subject/latest/articles',
#                                'vars': {'count': '2',
#                                         'heading': 'Latest Articles',
#                                         'image_param_string': 'w_300,h_250,c_fill,g_face:center,q_60,f_jpg'}},
#               'centerTop_12': {'description': 'this module is used to set up '
#                                               'the dfp slots on the page',
#                                'instance': 'ad text-align-center adx no-vis-30 '
#                                            'labeled_ad sweetart2',
#                                'name': 'ads/dfpslot',
#                                'vars': {'dfp_ad_unit': '51859126/parent_m_ar/gut_929_3',
#                                         'dfp_div_id': '300x250_3',
#                                         'dfp_height': '250',
#                                         'dfp_height_2': '50',
#                                         'dfp_height_3': '50',
#                                         'dfp_height_4': '280',
#                                         'dfp_width': '300',
#                                         'dfp_width_2': '320',
#                                         'dfp_width_3': '300',
#                                         'dfp_width_4': '336'}},
#               'centerTop_13': {'description': 'This is a latest article by '
#                                               'specified root category ordered '
#                                               'by published_at desc',
#                                'name': 'subject/latest/articles',
#                                'vars': {'count': '2',
#                                         'image_param_string': 'w_300,h_250,c_fill,g_face:center,q_60,f_jpg',
#                                         'show_heading': 'no'}},
#               'centerTop_14': {'description': 'this module is used to set up '
#                                               'the dfp slots on the page',
#                                'instance': 'ad text-align-center adx no-vis-30 '
#                                            'labeled_ad sweetart2',
#                                'name': 'ads/dfpslot',
#                                'vars': {'dfp_ad_unit': '51859126/parent_m_ar/gut_929_4',
#                                         'dfp_div_id': '300x250_4',
#                                         'dfp_height': '250',
#                                         'dfp_height_2': '50',
#                                         'dfp_height_3': '50',
#                                         'dfp_height_4': '280',
#                                         'dfp_width': '300',
#                                         'dfp_width_2': '320',
#                                         'dfp_width_3': '300',
#                                         'dfp_width_4': '336'}},
#               'centerTop_15': {'description': 'This is a latest article by '
#                                               'specified root category ordered '
#                                               'by published_at desc',
#                                'name': 'subject/latest/articles',
#                                'vars': {'count': '2',
#                                         'image_param_string': 'w_300,h_250,c_fill,g_face:center,q_60,f_jpg',
#                                         'show_heading': 'no'}},
#               'centerTop_16': {'description': 'Ads Rubicon slot for use '
#                                               'outside of DFP delivery',
#                                'instance': 'ad text-align-center adx no-vis-30 '
#                                            'ad_with_label ad300_250 sweetart2',
#                                'name': 'ads/rubicon',
#                                'vars': {'ad_slot_name': 'Answers_com_MWeb_RFM_300x250_2_ROS',
#                                         'height': '250',
#                                         'iframe_class': 'rubicon_300x250_1',
#                                         'rp_kw': 'gut_929_5',
#                                         'width': '300'}},
#               'centerTop_17': {'description': 'This is a latest article by '
#                                               'specified root category ordered '
#                                               'by published_at desc',
#                                'name': 'subject/latest/articles',
#                                'vars': {'count': '2',
#                                         'image_param_string': 'w_300,h_250,c_fill,g_face:center,q_60,f_jpg',
#                                         'show_heading': 'no'}},
#               'centerTop_2': {'name': 'carousel/ui/subtitle'},
#               'centerTop_3': {'description': 'this module is used to set up '
#                                              'the dfp slots on the page',
#                               'instance': 'ad text-align-center labeled_ad',
#                               'name': 'ads/dfpslot',
#                               'vars': {'dfp_ad_unit': '51859126/parent_m_ar/gut_929_1',
#                                        'dfp_div_id': '300x250_1',
#                                        'dfp_height': '250',
#                                        'dfp_height_2': '50',
#                                        'dfp_height_3': '50',
#                                        'dfp_width': '300',
#                                        'dfp_width_2': '320',
#                                        'dfp_width_3': '300'}},
#               'centerTop_4': {'name': 'carousel/ui/text'},
#               'centerTop_5': {'description': 'this module is used to set up '
#                                              'the dfp slots on the page',
#                               'instance': 'ad text-align-center adx no-vis-10 '
#                                           'before_nav labeled_ad sweetart '
#                                           'near_nav',
#                               'name': 'ads/dfpslot',
#                               'vars': {'dfp_ad_unit': '51859126/parent_m_ar/gut_929_2',
#                                        'dfp_div_id': '300x250_2',
#                                        'dfp_height': '250',
#                                        'dfp_height_2': '50',
#                                        'dfp_height_3': '50',
#                                        'dfp_height_4': '280',
#                                        'dfp_width': '300',
#                                        'dfp_width_2': '320',
#                                        'dfp_width_3': '300',
#                                        'dfp_width_4': '336'}},
#               'centerTop_6': {'description': 'Display an open or close div '
#                                              'tag, used to wrap modules in a '
#                                              'div',
#                               'instance': 'carousel_slideshow_buttons clearfix',
#                               'name': 'utility/wrapper',
#                               'vars': {'class': '', 'id': ''}},
#               'centerTop_7': {'description': 'flight componenet for navigating '
#                                              'backwards through a carousel',
#                               'name': 'carousel/ui/buttons/previous',
#                               'vars': {'button_text': 'PREV'}},
#               'centerTop_8': {'name': 'carousel/ui/buttons/next'},
#               'centerTop_9': {'description': 'Display an open or close div '
#                                              'tag, used to wrap modules in a '
#                                              'div',
#                               'instance': 'close',
#                               'name': 'utility/wrapper',
#                               'vars': {'class': '', 'id': '', 'type': 'close'}},
#               'footer_0': {'description': 'Simply places a block on the page '
#                                           'with whatever HTML (or css and '
#                                           'javascript) is configured. Tokens '
#                                           'available: {CURRENT_URL}',
#                            'instance': 'fban fban_interstitial',
#                            'name': 'html',
#                            'vars': {'location': 'feet',
#                                     'payload': '<script>\n'
#                                                'var fban_interstitial_config = '
#                                                '{\n'
#                                                "    'placementid': "
#                                                "'168416999909992_972806032804414',\n"
#                                                '\n'
#                                                "    'trigger_on_timer': "
#                                                'false,\n'
#                                                "    'timer_seconds': null,\n"
#                                                '\n'
#                                                "    'trigger_on_slide_change': "
#                                                'true,\n'
#                                                "    'slide_count_start': 5,\n"
#                                                '    '
#                                                "'slide_count_repeat_interval': "
#                                                '5\n'
#                                                '};\n'
#                                                '</script>\n'
#                                                '<style>\n'
#                                                '.module.fban_interstitial {\n'
#                                                '  display: block;\n'
#                                                '  background: white;\n'
#                                                '  height: 0;\n'
#                                                '  width: 0;\n'
#                                                '  position: absolute;\n'
#                                                '  overflow: hidden;\n'
#                                                '  z-index: -999;\n'
#                                                '  opacity: 0;\n'
#                                                '  margin: 0;\n'
#                                                '  padding: 0;\n'
#                                                '  border: none;\n'
#                                                '}\n'
#                                                '.module.fban_interstitial.adloaded '
#                                                '{\n'
#                                                '  height: 100%;\n'
#                                                '  width: 100%;\n'
#                                                '  height: '
#                                                '-webkit-calc(100vh);\n'
#                                                '  width: -webkit-calc(100vw);\n'
#                                                '  height: calc(100vh);\n'
#                                                '  width: calc(100vw);\n'
#                                                '  position: fixed;\n'
#                                                '  top: 0;\n'
#                                                '  right: 0;\n'
#                                                '  bottom: 0;\n'
#                                                '  left: 0;\n'
#                                                '  z-index: 999;\n'
#                                                '  opacity: 1;\n'
#                                                '  display: none;\n'
#                                                '}\n'
#                                                '.isMobileSafari '
#                                                '.module.fban_interstitial.adloaded '
#                                                '{\n'
#                                                '  height: 100%;\n'
#                                                '  width: 100%;\n'
#                                                '}\n'
#                                                '.module.fban_interstitial '
#                                                '.fb_iframe_widget {\n'
#                                                '  position: absolute;\n'
#                                                '  top: -30px;\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fban_interstitial_close {\n'
#                                                '  position: absolute;\n'
#                                                '  top: 5px;\n'
#                                                '  right: 5px;\n'
#                                                '  padding: 5px;\n'
#                                                '  text-align: center;\n'
#                                                '  cursor: pointer;\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fban_interstitial_close span '
#                                                '{\n'
#                                                '  font-family: Arial, '
#                                                'sans-serif;\n'
#                                                '  font-size: 40px;\n'
#                                                '  font-weight: normal;\n'
#                                                '  background: rgba(0,0,0, '
#                                                '0.33);\n'
#                                                '  box-shadow: 0 0 3px '
#                                                'rgba(255,255,255, 0.2);\n'
#                                                '  color: #eee;\n'
#                                                '  border-radius: 50px;\n'
#                                                '  display: block;\n'
#                                                '  width: 50px;\n'
#                                                '  height: 50px;\n'
#                                                '  line-height: 50px;\n'
#                                                '  overflow: hidden;\n'
#                                                '}\n'
#                                                '.fban_interstitial .fbAdLink '
#                                                '{\n'
#                                                '  display: block;\n'
#                                                '  height: 100%;\n'
#                                                '  width: 100%;\n'
#                                                '}\n'
#                                                '.fban_interstitial .fbAdMedia '
#                                                '{\n'
#                                                '  background: center center '
#                                                'no-repeat;\n'
#                                                '  background-size: cover;\n'
#                                                '  -webkit-animation: '
#                                                'paninterstitial 10s infinite;\n'
#                                                '  '
#                                                '-webkit-animation-timing-function: '
#                                                'ease-in-out;\n'
#                                                '  animation: paninterstitial '
#                                                '10s infinite;\n'
#                                                '  animation-timing-function: '
#                                                'ease-in-out;\n'
#                                                '  position: relative;\n'
#                                                '  padding: 0 0 75% 0; /* 4:3 '
#                                                '*/\n'
#                                                '  height: 0;\n'
#                                                '  box-shadow: inset 0 0px 35px '
#                                                'rgba(0,0,0,.2);\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fban_interstitial_top {\n'
#                                                '  position: relative;\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fban_interstitial_top '
#                                                '.fbAdIcon {\n'
#                                                '  text-align: center;\n'
#                                                '  position: absolute;\n'
#                                                '  bottom: -35px;\n'
#                                                '  width: 100%;\n'
#                                                '}\n'
#                                                '.fban_interstitial .fbAdIcon '
#                                                'img {\n'
#                                                '  width: 60px !important;\n'
#                                                '  height: 60px !important;\n'
#                                                '  margin: auto;\n'
#                                                '  box-shadow: 0 3px 8px '
#                                                'rgba(0,0,0,.3);\n'
#                                                '  -webkit-box-sizing: '
#                                                'content-box;\n'
#                                                '  box-sizing: content-box;\n'
#                                                '  border: 1px solid #333;\n'
#                                                '  outline: 3px solid #fff;\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fban_interstitial_body {\n'
#                                                '    color: #666;\n'
#                                                '    font-size: 13px;\n'
#                                                '    padding: 40px 20px 0;\n'
#                                                '    text-align: center;\n'
#                                                '}\n'
#                                                '.fban_interstitial .fbAdTitle '
#                                                '{\n'
#                                                '    color: #333;\n'
#                                                '    font-size: 18px;\n'
#                                                '    font-weight: bold;\n'
#                                                '    padding: 10px 0 15px;\n'
#                                                '    letter-spacing: -.05em;\n'
#                                                '    line-height: 1.5em;\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fbAdSubtitle {\n'
#                                                '    display: none;\n'
#                                                '    color: #999;\n'
#                                                '    margin-top: -10px;\n'
#                                                '    margin-bottom: 10px;\n'
#                                                '    letter-spacing: .04em;\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fbAdSocialContext {\n'
#                                                '    color: #999;\n'
#                                                '    margin-top: -10px;\n'
#                                                '    margin-bottom: 10px;\n'
#                                                '    letter-spacing: .04em;\n'
#                                                '    text-decoration: '
#                                                'underline;\n'
#                                                '}\n'
#                                                '.fban_interstitial .fbAdBody '
#                                                '{\n'
#                                                '    font-size: 16px;\n'
#                                                '    line-height: 1.5em;\n'
#                                                '    padding: 15px 0;\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fbAdCallToActionWrapper {\n'
#                                                '    background: '
#                                                'rgba(255,255,255,.8);\n'
#                                                '    position: absolute;\n'
#                                                '    bottom: 0;\n'
#                                                '    width: 100%;\n'
#                                                '    padding: 20px 10px 25px;\n'
#                                                '    text-align: center;\n'
#                                                '    box-shadow: 0 0 30px '
#                                                'rgba(0,0,0,0.1);\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fbAdCallToActionWrapper '
#                                                '.fbAdIcon {\n'
#                                                '    display: none;\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fbAdCallToAction {\n'
#                                                '    position: relative;\n'
#                                                '    color: #ffffff;\n'
#                                                '    text-decoration: none;\n'
#                                                "    font-family: 'Oswald', "
#                                                "'Helvetica Neue', 'Open Sans', "
#                                                "'Arial';\n"
#                                                '    display: block;\n'
#                                                '    border-radius: 6px;\n'
#                                                '    text-align: center;\n'
#                                                '    -webkit-transform: '
#                                                'translate(0, 0);\n'
#                                                '    -moz-transform: '
#                                                'translate(0, 0);\n'
#                                                '    transform: translate(0, '
#                                                '0);\n'
#                                                '    transition: all .2s ease;\n'
#                                                '    cursor: pointer;\n'
#                                                '    overflow: hidden;\n'
#                                                '    text-shadow: none;\n'
#                                                '    box-shadow: 0px 6px 0px '
#                                                'rgb(44, 193, 45);\n'
#                                                '    background: rgb(72, 212, '
#                                                '73);\n'
#                                                '    border: none;\n'
#                                                '    outline: none;\n'
#                                                '    white-space: nowrap;\n'
#                                                '    padding: 7px 30px 4px;\n'
#                                                '    letter-spacing: .1em;\n'
#                                                '    margin: auto;\n'
#                                                '    z-index: 999;\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fbAdCallToAction:active {\n'
#                                                '    box-shadow: 0px 2px 0px '
#                                                'rgb(44, 193, 45);\n'
#                                                '}\n'
#                                                '@-webkit-keyframes '
#                                                'paninterstitial {\n'
#                                                '    0% { background-position: '
#                                                '50%; }\n'
#                                                '    20% { background-position: '
#                                                '50%; }\n'
#                                                '    30% { background-position: '
#                                                '0%; }\n'
#                                                '    70% { background-position: '
#                                                '100%; }\n'
#                                                '    80% { background-position: '
#                                                '50%; }\n'
#                                                '    100% { '
#                                                'background-position: 50%; }\n'
#                                                '}\n'
#                                                '@keyframes paninterstitial {\n'
#                                                '    0% { background-position: '
#                                                '50%; }\n'
#                                                '    20% { background-position: '
#                                                '50%; }\n'
#                                                '    30% { background-position: '
#                                                '0%; }\n'
#                                                '    70% { background-position: '
#                                                '100%; }\n'
#                                                '    80% { background-position: '
#                                                '50%; }\n'
#                                                '    100% { '
#                                                'background-position: 50%; }\n'
#                                                '}\n'
#                                                '\n'
#                                                '\n'
#                                                '@media (orientation: '
#                                                'landscape) {\n'
#                                                '    .fban_interstitial '
#                                                '.fbAdMediaWrapper {\n'
#                                                '      height: 100%;\n'
#                                                '        position: absolute;\n'
#                                                '        top: 0;\n'
#                                                '        bottom: 0;\n'
#                                                '        left: 0;\n'
#                                                '        right: 0;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fbAdMedia {\n'
#                                                '      height: 100%;\n'
#                                                '        position: absolute;\n'
#                                                '        top: 0;\n'
#                                                '        bottom: 0;\n'
#                                                '        left: 0;\n'
#                                                '        right: 0;\n'
#                                                '      padding: 0;\n'
#                                                '      height: auto;\n'
#                                                '      background-size: '
#                                                'contain;\n'
#                                                '      background-color: #000;\n'
#                                                '      -webkit-animation: '
#                                                'none;\n'
#                                                '      animation: none;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fban_interstitial_top {\n'
#                                                '      position: absolute;\n'
#                                                '      top: 0;\n'
#                                                '      right: 0;\n'
#                                                '      bottom: 70px;\n'
#                                                '      left: 0;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fban_interstitial_top '
#                                                '.fbAdIcon {\n'
#                                                '      position: absolute;\n'
#                                                '      top: 0;\n'
#                                                '      right: 0;\n'
#                                                '      bottom: 70px;\n'
#                                                '      left: 0;\n'
#                                                '      display: none;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fban_interstitial_body {\n'
#                                                '      position: absolute;\n'
#                                                '      width: auto;\n'
#                                                '      padding: 0;\n'
#                                                '      bottom: 0px;\n'
#                                                '      left: 70px;\n'
#                                                '      right: 110px;\n'
#                                                '      text-align: left;\n'
#                                                '      z-index: 999;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fbAdTitle {\n'
#                                                '      padding: 10px 0;\n'
#                                                '      font-size: 15px;\n'
#                                                '      font-weight: normal;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fbAdSubtitle,\n'
#                                                '    .fban_interstitial '
#                                                '.fbAdBody {\n'
#                                                '        display: none;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fbAdCallToActionWrapper {\n'
#                                                '      height: 70px;\n'
#                                                '      padding: 0 10px;\n'
#                                                '      text-align: right;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fbAdCallToActionWrapper '
#                                                '.fbAdIcon {\n'
#                                                '      display: block;\n'
#                                                '      width: 50px;\n'
#                                                '      height: 50px;\n'
#                                                '      position: absolute;\n'
#                                                '      left: 10px;\n'
#                                                '      top: 10px;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fbAdCallToActionWrapper '
#                                                'button {\n'
#                                                '      margin: 0;\n'
#                                                '      position: absolute;\n'
#                                                '      top: 10px;\n'
#                                                '      right: 10px;\n'
#                                                '      bottom: 15px;\n'
#                                                '      padding: 0 10px;\n'
#                                                '      font-weight: normal;\n'
#                                                '      font-size: 14px;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fbAdCallToActionWrapper '
#                                                '.fbAdIcon img {\n'
#                                                '      height: 100% '
#                                                '!important;\n'
#                                                '      width: 100% !important;\n'
#                                                '    }\n'
#                                                '}\n'
#                                                '</style>\n'
#                                                '\n'
#                                                '<div '
#                                                'id="fban_interstitial_template" '
#                                                'class="module html '
#                                                'fban_interstitial">\n'
#                                                '    <fb:ad\n'
#                                                '        '
#                                                'nativeadid="fban_unit_interstitial_1"\n'
#                                                '        placementid=""\n'
#                                                '        format="native"\n'
#                                                '        '
#                                                'testmode="false"></fb:ad>\n'
#                                                '    <div '
#                                                'id="fban_unit_interstitial_1">\n'
#                                                '      <a class="fbAdLink">\n'
#                                                '        <div '
#                                                'class="fban_interstitial_top">\n'
#                                                '            <div '
#                                                'class="fbAdMedia"></div>\n'
#                                                '            <div '
#                                                'class="fbAdIcon"></div>\n'
#                                                '        </div>\n'
#                                                '        <div '
#                                                'class="fban_interstitial_body">\n'
#                                                '          <div '
#                                                'class="fbAdTitle"></div>\n'
#                                                '          <div '
#                                                'class="fbAdSocialContext"></div>\n'
#                                                '          <div '
#                                                'class="fbAdSubtitle"></div>\n'
#                                                '          <div '
#                                                'class="fbAdBody"></div>\n'
#                                                '        </div>\n'
#                                                '        <div '
#                                                'class="fbAdCallToActionWrapper">\n'
#                                                '            <div '
#                                                'class="fbAdIcon"></div>\n'
#                                                '            <button '
#                                                'class="fbAdCallToAction"></button>\n'
#                                                '        </div>\n'
#                                                '      </a>\n'
#                                                '      <div '
#                                                'class="fban_interstitial_close" '
#                                                'aria-label="Close '
#                                                'Ad"><span>Ã—</span></div>\n'
#                                                '    </div>\n'
#                                                '</div>\n'
#                                                '\n'
#                                                '\n'
#                                                '<script>\n'
#                                                '(function(){\n'
#                                                '    var config = '
#                                                'fban_interstitial_config;\n'
#                                                '    var $template = '
#                                                "$('#fban_interstitial_template');\n"
#                                                '    if(!config.placementid){\n'
#                                                '      $template.hide();\n'
#                                                '      return;\n'
#                                                '    }\n'
#                                                '    '
#                                                "$template.find('fb\\\\:ad').attr('placementid', "
#                                                'config.placementid);\n'
#                                                '    var fbani_template = '
#                                                "$('#fban_interstitial_template').html();\n"
#                                                '    var slide_change_count = '
#                                                '1;\n'
#                                                '    var first_shown = false;\n'
#                                                '    function isMobileSafari() '
#                                                '{\n'
#                                                '      return '
#                                                'navigator.userAgent.match(/(iPod|iPhone|iPad)/) '
#                                                '&& '
#                                                'navigator.userAgent.match(/AppleWebKit/);\n'
#                                                '    }\n'
#                                                '    if(isMobileSafari()){\n'
#                                                '      '
#                                                "$('body').addClass('isMobileSafari');\n"
#                                                '    }\n'
#                                                '    '
#                                                'if(config.trigger_on_slide_change){\n'
#                                                '        $([document, '
#                                                "document.body]).on('carousel_slide_change', "
#                                                'function(){\n'
#                                                '            '
#                                                'slide_change_count++;\n'
#                                                '            '
#                                                "if(!$('.module.fban_interstitial.adloaded:first').length){\n"
#                                                '                '
#                                                'fban_interstitial_refresh();\n'
#                                                '            }else{\n'
#                                                '                '
#                                                'if(!first_shown){\n'
#                                                '                    '
#                                                'if(!isNaN(config.slide_count_start)){\n'
#                                                '                        '
#                                                'if(slide_change_count >= '
#                                                'config.slide_count_start){\n'
#                                                '                            '
#                                                "$(document).trigger('fban_show_interstitial');\n"
#                                                '                        }\n'
#                                                '                    }\n'
#                                                '                }else '
#                                                'if(!isNaN(config.slide_count_repeat_interval)){\n'
#                                                '                    '
#                                                'if(slide_change_count >= '
#                                                'config.slide_count_repeat_interval){\n'
#                                                '                        '
#                                                "$(document).trigger('fban_show_interstitial');\n"
#                                                '                    }\n'
#                                                '                }\n'
#                                                '            }\n'
#                                                '        });\n'
#                                                '    }\n'
#                                                '    FB.Event.subscribe(\n'
#                                                "        'ad.loaded',\n"
#                                                '        function(placementid) '
#                                                '{\n'
#                                                '            if(placementid !== '
#                                                'config.placementid){\n'
#                                                '              return;\n'
#                                                '            }\n'
#                                                '            var $fbani = '
#                                                "$('.module.fban_interstitial:first');\n"
#                                                '            '
#                                                "if($fbani.find('.fbAdTitle:first').text() "
#                                                "=== ''){\n"
#                                                '                // LIARS!\n'
#                                                '                // '
#                                                "console.log('FBAN: no ad "
#                                                "title');\n"
#                                                '                '
#                                                'fban_interstitial_refresh();\n'
#                                                '                return;\n'
#                                                '            }\n'
#                                                '            var $img = '
#                                                "$fbani.find('.fbAdMedia "
#                                                "img');\n"
#                                                '            if($img.length){\n'
#                                                '                $fbani\n'
#                                                '                    '
#                                                ".find('.fbAdMedia')\n"
#                                                '                    '
#                                                ".css({'background-image':'url('+JSON.stringify($img.attr('src'))+')'});\n"
#                                                '                '
#                                                "$img.css('opacity',0);\n"
#                                                '            }else{\n'
#                                                '                // Broken .. '
#                                                'not showing\n'
#                                                '                // '
#                                                "console.log('FBAN: bad "
#                                                "fbAdMedia', "
#                                                "$fbani.find('.fbAdMedia').html());\n"
#                                                '                '
#                                                'fban_interstitial_refresh();\n'
#                                                '                return;\n'
#                                                '            }\n'
#                                                '            '
#                                                "$fbani.addClass('adloaded');\n"
#                                                '            // special case '
#                                                'for onpageload display\n'
#                                                '            if(\n'
#                                                '                '
#                                                'config.trigger_on_slide_change \n'
#                                                '                && '
#                                                '!first_shown \n'
#                                                '                && '
#                                                'config.slide_count_start === '
#                                                '1 \n'
#                                                '                && '
#                                                'slide_change_count === 1\n'
#                                                '            ){\n'
#                                                '                '
#                                                "$(document).trigger('fban_show_interstitial');\n"
#                                                '            }\n'
#                                                '        }\n'
#                                                '    );\n'
#                                                '    FB.Event.subscribe(\n'
#                                                "        'ad.error',\n"
#                                                '        function(errorCode, '
#                                                'errorMessage, placementid) {\n'
#                                                '            // '
#                                                "console.log('ad.error', "
#                                                'arguments);\n'
#                                                '            if(placementid !== '
#                                                'config.placementid){\n'
#                                                '              return;\n'
#                                                '            }\n'
# ...
#                                                '\t\t-webkit-transform: '
#                                                'translate(0, -50%);\n'
#                                                '\t\t-moz-transform: '
#                                                'translate(0, -50%);\n'
#                                                '\t\t-ms-transform: '
#                                                'translate(0, -50%);\n'
#                                                '\t\t-o-transform: translate(0, '
#                                                '-50%);\n'
#                                                '\t\ttransform: translate(0, '
#                                                '-50%);\n'
#                                                '\t}\n'
#                                                '\n'
#                                                '\n'
#                                                '\t/** FORMAT TOGGLE STYLES '
#                                                '**/\n'
#                                                '\t.format_toggle .option {\n'
#                                                '\t\tdisplay: block;\n'
#                                                '\t\tfloat: left;\n'
#                                                '\t\tpadding: 8px 6px;\n'
#                                                '\t\tbackground-color: '
#                                                '#1E78D7;\n'
#                                                '\t\tborder: 1px solid '
#                                                '#0854cf;\n'
#                                                '\t\ttext-align: center;\n'
#                                                '\t\tfont-size: .75em;\n'
#                                                '\t\ttext-decoration: none;\n'
#                                                '\t\tcolor: #fff;\n'
#                                                '\n'
#                                                '\t\t-webkit-transition: '
#                                                'border-color 50ms;\n'
#                                                '\t\t-moz-transition: '
#                                                'border-color 50ms;\n'
#                                                '\t\ttransition: border-color '
#                                                '50ms;\n'
#                                                '\t}\n'
#                                                '\t.format_toggle .option:hover '
#                                                '{\n'
#                                                '\t\tbackground-color: '
#                                                '#d7d8d8;\n'
#                                                '\t\tcolor: #fff;\n'
#                                                '\t}\n'
#                                                '\t.format_toggle '
#                                                '.option:first-child {\n'
#                                                '\t\tborder-radius: 3px 0 0 '
#                                                '3px;\n'
#                                                '\t}\n'
#                                                '\t.format_toggle '
#                                                '.option:nth-child(2) {\n'
#                                                '\t\tborder-right-width: 0;\n'
#                                                '\t\tborder-left-width: 0;\n'
#                                                '\t}\n'
#                                                '\t.format_toggle '
#                                                '.option:last-child {\n'
#                                                '\t\tborder-radius: 0 3px 3px '
#                                                '0;\n'
#                                                '\t}\n'
#                                                '\t.format_toggle '
#                                                '.option.selected {\n'
#                                                '\t\tbackground-color: '
#                                                '#1562D2;\n'
#                                                '\t\tborder-color: #0854cf;\n'
#                                                '\t\tcolor: #fff;\n'
#                                                '\t}\n'
#                                                '\t.format_toggle '
#                                                '.option.disabled {\n'
#                                                '\t\tpointer-events: none;\n'
#                                                '\t\tcursor: default;\n'
#                                                '\t}\n'
#                                                '\t.format_toggle '
#                                                '.option.disabled:hover {\n'
#                                                '\t\tcolor: #c3c4c5 '
#                                                '!important;\n'
#                                                '\t}\n'
#                                                '\n'
#                                                '\t.format_toggle .option .fa '
#                                                '{\n'
#                                                '\t\tposition: relative;\n'
#                                                '\t\ttop: -1px;\n'
#                                                '\t}\n'
#                                                '</style>\n'
#                                                '\n'
#                                                '<header '
#                                                'class="header_mobile_gute '
#                                                'clearfix">\n'
#                                                '\t<figure class="logo">\n'
#                                                '\t\t<a track="home_tools/PAGE" '
#                                                'title="Answers.com home" '
#                                                'href="http://www.answers.com">\n'
#                                                '\t\t\t<svg width="115" '
#                                                'height="30">\n'
#                                                '\t\t\t\t<image '
#                                                'xmlns:xlink="http://www.w3.org/1999/xlink" '
#                                                'xlink:href="//rxs1.answcdn.com/includes/images/redcarpet/answers-logo-white.svg" '
#                                                'width="115" height="30" '
#                                                'src="//rxs1.answcdn.com/includes/images/onboarding/answers-logo-white.png">\n'
#                                                '\t\t\t</svg>\n'
#                                                '\t\t</a>\n'
#                                                '\t</figure>\n'
#                                                '</header>\n'
#                                                '\n'
#                                                '\n'
#                                                '\n'
#                                                '<script>\n'
#                                                '\t(function() {\n'
#                                                '\n'
#                                                '\t\tvar getLmi = function() {\n'
#                                                '\t\t\treturn '
#                                                'decodeURIComponent(document.cookie.replace(new '
#                                                'RegExp("(?:(?:^|.*;)\\\\s*" + '
#                                                "encodeURIComponent('mode_id').replace(/[\\-\\.\\+\\*]/g, "
#                                                '"\\\\$&") + '
#                                                '"\\\\s*\\\\=\\\\s*([^;]*).*$)|^.*$"), '
#                                                '"$1")) || null;\n'
#                                                '\t\t};\n'
#                                                '\n'
#                                                '\t\tvar getPostId = function() '
#                                                '{\n'
#                                                '\t\t\tvar id = '
#                                                "location.pathname.split('/')[2];\n"
#                                                '\n'
#                                                '\t\t\tif (isNaN(id) === true) '
#                                                '{\n'
#                                                '\t\t\t\tid = '
#                                                "$('.current_batch').data('batch-id') "
#                                                '|| 0;\n'
#                                                '\t\t\t}\n'
#                                                '\n'
#                                                '\t\t\treturn id;\n'
#                                                '\t\t};\n'
#                                                '\n'
#                                                '\t\tvar check_videos = '
#                                                'function () {\n'
#                                                '\t\t\t$(function () {\n'
#                                                "\t\t\t\tvar url =  '//' + "
#                                                'location.host + '
#                                                "'/endpoint/guides/posts/sections',\n"
#                                                '\t\t\t\t\tid = getPostId();\n'
#                                                '\n'
#                                                '\t\t\t\t$.ajax({\n'
#                                                '\t\t\t\t\turl: url,\n'
#                                                "\t\t\t\t\ttype: 'GET',\n"
#                                                "\t\t\t\t\tdataType: 'json',\n"
#                                                '\t\t\t\t\tdata: {posts_id: '
#                                                'id},\n'
#                                                '\t\t\t\t\terror: function '
#                                                '(one, two, three) {\n'
#                                                '\t\t\t\t\t},\n'
#                                                '\t\t\t\t\tsuccess: function '
#                                                '(data) {\n'
#                                                '\t\t\t\t\t\tif (data.error) {\n'
#                                                '\t\t\t\t\t\t\t'
#                                                "$('.format_toggle "
#                                                ".option.video').remove();\n"
#                                                '\t\t\t\t\t\t\t'
#                                                "$('.format_toggle').addClass('thin');\n"
#                                                '\t\t\t\t\t\t\treturn false;\n'
#                                                '\t\t\t\t\t\t}\n'
#                                                '\n'
#                                                '\t\t\t\t\t\tvar results = '
#                                                'data.result,\n'
#                                                '\t\t\t\t\t\t\tlen = '
#                                                'results.length,\n'
#                                                '\t\t\t\t\t\t\ti=0;\n'
#                                                '\n'
#                                                '\t\t\t\t\t\tfor (; i < len; '
#                                                'i++) {\n'
#                                                '\t\t\t\t\t\t\tvar d = '
#                                                'results[i];\n'
#                                                '\n'
#                                                '\t\t\t\t\t\t\tif (d.type === '
#                                                "'video') {\n"
#                                                '\t\t\t\t\t\t\t\t'
#                                                "$('.format_toggle "
#                                                ".option.video').removeClass('disabled');\n"
#                                                '\t\t\t\t\t\t\t\treturn true;\n'
#                                                '\t\t\t\t\t\t\t}\n'
#                                                '\t\t\t\t\t\t}\n'
#                                                '\t\t\t\t\t}\n'
#                                                '\t\t\t\t});\n'
#                                                '\t\t\t});\n'
#                                                '\t\t};\n'
#                                                '\n'
#                                                '\t\tvar initialize = '
#                                                'function() {\n'
#                                                '\t\t\t$(function () {\n'
#                                                '\t\t\t\t'
#                                                "$('.controls').children().each(function() "
#                                                '{\n'
#                                                '\t\t\t\t\t'
#                                                '$(this).click(function(e) {\n'
#                                                '\t\t\t\t\t\tvar type = '
#                                                "$(e.target).attr('data-type');\n"
#                                                '\t\t\t\t\t\t'
#                                                "_gaq.push(['_trackEvent', "
#                                                "'Article Format', type + ' "
#                                                "click', 'param4-' + getLmi() + "
#                                                "'-' + getPostId() + '-' + "
#                                                'type]);\n'
#                                                '\t\t\t\t\t});\n'
#                                                '\t\t\t\t});\n'
#                                                '\t\t\t});\n'
#                                                '\t\t};\n'
#                                                '\n'
#                                                '\t\tinitialize();\n'
#                                                '\t\tcheck_videos();\n'
#                                                '\n'
#                                                '\t}());\n'
#                                                '</script>'}},
#               'header_3': {'name': 'js/head/scripts/home'},
#               'header_4': {'name': 'js/login'},
#               'header_5': {'name': 'js/decoderedirect'},
#               'header_6': {'description': '',
#                            'name': 'tracking/googleanalytics',
#                            'vars': {'custom_variable_1': 'null_mod_override_ar_55825',
#                                     'track_fb_status': 'off'}},
#               'header_7': {'name': 'js/metatags',
#                            'vars': {'keyword-title-suffix': '',
#                                     'page_type': 'gutenberg',
#                                     'profile_title_suffix': ''}},
#               'header_8': {'description': 'Module for configuring a Gutenberg '
#                                           'article slideshow and adapting data '
#                                           'to presentation.',
#                            'name': 'carousel/slideshow',
#                            'vars': {'chunk_on_punctuation': 'yes',
#                                     'image_param_string': 'w_728,c_fill,g_face:center,q_60,f_jpg',
#                                     'make_section_title_a_pane': 'no',
#                                     'text_chunk_size': '100'}},
#               'header_9': {'description': 'this module is used to set up the '
#                                           'dfp slots on the page',
#                            'instance': 'dfp_1x1',
#                            'name': 'ads/dfpslot',
#                            'vars': {'dfp_ad_unit': '/51859126/answ_mobile_1x1',
#                                     'dfp_div_id': 'answ_mobile_1x1',
#                                     'dfp_height': '1',
#                                     'dfp_width': '1'}}},
#  'selective_css': '1',
#  'skin': 'red-carpet',
#  'theme': '3-col-responsive'}

# %%
#Set constants

OpenX_ids = {"728": "537088038" , "160": "537088042" , "300": "537088040"}
Casale_ids = {"728": "154714", "160": "154714", "300": "154714"}
ids = [OpenX_ids, Casale_ids]

#Make sure IDs are strings
for i in ids:
    for key in i:
        i[key] = str(i[key])
# Out:
# True

# %% [markdown]
# # functions

# %%
def lmiTagging(json, tag, openx_ids, casale_ids):
    if tag[:2] == "gu":
            replaceDFPUnits_Mobile(json,tag)
    elif tag[:2] == "ar":
        replaceDFPUnits_Desktop(json, tag, openx_ids, casale_ids)

#Mobile Functions
'''Replaces ad units in '''
def replaceDFPUnits_Mobile(json, tag):
    tag = tagging(tag)
    if len(tag.group()) <= 7:
        adunitPre = "51859126/parent_m_ar" + "/" + str(tag.group())
    else:
        adunitPre = "51859126/parent_m_ar_" + str(tag.group(2)) + "/" + str(tag.group())
    for module in json['partials']:
        name = json['partials'][module]['name']
        if name == 'ads/dfpslot' and json['partials'][module]['vars']['dfp_height'] != '1' :
            json['partials'][module]['vars']['dfp_ad_unit'] = adunitPre + str(determineAdSlot(json['partials'][module]['vars']['dfp_ad_unit']))
        elif name == 'ads/rubicon':
            json['partials'][module]['vars']['rp_kw'] = str(tag.group()) + "_5"
        elif name == 'ads/outbrain':
            json['partials'][module]['vars']['variant'] = str(tag.group()) + "_1"
    return json

#Desktop Functions
#/51859126/parent_ar_roa/child_ar_roa_2/roa2_728x90_2
#/51859126/parent_ar/child_ar_60/ar60_160x600_1
#/51859126/parent_m_ar_roa/gut_roa_m_25_1
#/51859126/parent_m_ar/gut_825_1

def replaceDFPUnits_Desktop(json, tag, siteCode, openx_ids, casale_ids):
    #replaces all ad units with a given tag
    tag = tagging(tag)
    for module in json['partials']:
        if len(tag.group()) <= 5:
            adunitPre = "51859126/parent_ar" + "/" + "child_ar_" + str(tag.group(2)) + "/" + str(tag.group())
        else:
            adunitPre = "51859126/parent_ar_" + str(tag.group(3)) + "/" + "child_ar_" + str(tag.group(3)) + "_" + str(tag.group(5)) + "/" + str(tag.group(2))
        name = json['partials'][module]['name']
        ad_unit = json['partials'][module]
        #Replace DFP ad units
        if name == 'ads/dfpslot':
            ad_unit['vars']['dfp_ad_unit'] = adunitPre + "_" + str(determineAdSize(json['partials'][module]['vars']['dfp_width'])) + str(determineAdSlot(json['partials'][module]['vars']['dfp_ad_unit']))
        elif name == 'ads/outbrain':
            json['partials'][module]['vars']['variant'] = str(tag) + "_1"
        elif name == 'links/openx':
            replaceOpenX(module, openx_ids)
        elif name == 'links/casale':
            replaceCasale(module, casale_id)
        elif name == 'video/universal':
            json['partials'][module]['vars']['ad_tag'] = 'http://vast.optimatic.com/vast/getVast.aspx?id=a253n547s864w&zone=' + str(tag) + '&pageURL=__page-url__&pageTitle=__video-title__&cb=__random-number'
    return json

#Helper functions  

"""The tagging function breaks up a given tag into components so that other functions can access information about the site and tag.
   Tags take the following four forms:
   1) gut_XXX_m_YYY --> XXX: group(2), YYY: group(4)
   2) ar_XXXYYY --> XXX: group(3), YYY: group(5) XXXYYY: group(2)
   3) gut_YYY --> YYY: group(1)
   4) arYYY --> YYY: group(2)
   
   The entire tag can be accessed by calling .group() on the regex object. Accessing different parts of the tag can be done by referencing the mapping above
"""
def tagging(tag):
    if tag[:3] != "gut":
        tagRegexD = re.compile(r'ar(_?)(((\w\w\w)?)((\d?)(\d?)(\d?)))')
        tagging = tagRegexD.search(tag)
    else:
        tagRegex = re.compile(r'gut_(\w\w\w?)((_m_)?)((\d?)(\d?)(\d?))')
        tagging = tagRegex.search(tag)
    return tagging
    

def determineAdSlot(ad_unit):
    end = ad_unit[-2:] 
    return end
    
def determineAdSize(ad_unit):
    if ad_unit == '300':
        return "300x250"
    elif ad_unit == '728':
        return "728x90"
    elif ad_unit == '160':
        return "160x600"
    
def replaceDFP_Desktop(module):
    if json['partials'][module]['name'] == 'ads/dfpslot':
        ad_unit['dfp_ad_unit'] = "51859126/parent_ar/" + "child_ar_" + str(tag[-2:]) + "/" + str(tag) + "_" + str(determineAdSize(varz['dfp_width']))
        
def replaceDFP_Mobile(module):
    if module['name'] == 'ads/dfpslot':
        module['dfp_ad_unit'] = "51859126/parent_m_ar/" + str(tag) + str(determineAdSlot(json['partials'][module]['vars']['dfp_ad_unit']))

def replaceOB(module):
    if module['name'] == 'ads/outbrain':
        module['vars']['variant'] = str(tag) + "_1"

def replaceCasale(module, casale_id):
    varz = json['partials'][module]['vars']
    if varz['width'] == '728':
        varz['casale_id'] = casale_ids["728"]
    elif varz['width'] == '160':
        varz['casale_id'] = casale_ids["160"]
    elif varz['width'] == '300':
        varz['casale_id'] = casale_ids["300"]
    return varz
        
def replaceOpenX(varz, OpenX_ids):
    varz = json['partials'][module]['vars']
    if varz['width'] == '728':
        varz['auid'] = openx_ids["728"]
    elif varz['width'] == '160':
        varz['auid'] = openx_ids["160"]
    elif varz['width'] == '300':
        varz['auid'] = openx_ids["300"]
    return varz
                
    
#QA Functions   
def QA_div_id():
     for module in json['partials']:
        if json['partials'][module]['name'] == 'ads/dfpslot':
            json['partials'][module]['vars'] = tag

# %%
tag = tagging("ar_roa100")
tag.group(3)
# Out:
# 'roa'

# %%
json_data4 = replaceDFPUnits_Desktop2(json_dict,"ar50","",Casale_ids,OpenX_ids)
pprint(json_data4)
# Out:
# {'ads': 0,
#  'adsnip': [],
#  'compactor': 'on',
#  'partials': {'centerTop_0': {'instance': 'gute_slideshow',
#                               'name': 'utility/wrapper'},
#               'centerTop_1': {'description': 'Includes Facebook, Pinterest, '
#                                              'Linkedin, Reddit, Twitter, '
#                                              'Google+, StumbleUpon, and Tumblr',
#                               'name': 'social/share/box',
#                               'vars': {'enable_googleplus': 'no',
#                                        'enable_twitter': 'no',
#                                        'heading': 'Share this article',
#                                        'label': 'long'}},
#               'centerTop_10': {'instance': 'close',
#                                'name': 'utility/wrapper',
#                                'vars': {'type': 'close'}},
#               'centerTop_11': {'description': 'this module is used to set up '
#                                               'the dfp slots on the page',
#                                'dfp_ad_unit': '51859126/parent_ar_/child_ar_00/ar_100__1',
#                                'instance': 'expert_desktop_enter_728x90_1',
#                                'name': 'ads/dfpslot',
#                                'vars': {'dfp_ad_unit': '51859126/parent_ar/child_ar_50/ar50_728x90_1',
#                                         'dfp_div_id': 'ar89_728x90_1',
#                                         'dfp_height': '90',
#                                         'dfp_height_2': '250',
#                                         'dfp_width': '728',
#                                         'dfp_width_2': '970'}},
#               'centerTop_12': {'description': 'Feed Card Module Using '
#                                               'Gutenberg For Contents',
#                                'name': 'feedcards/gutenberg',
#                                'vars': {'max_length': '175', 'page': '1'}},
#               'centerTop_13': {'description': 'OpenX Ad slot for use outside '
#                                               'of DFP delivery',
#                                'instance': '728x90_3',
#                                'name': 'links/openx',
#                                'vars': {'ad_slot_name': 'expert_desktop_all_728x90_3',
#                                         'auid': '537088038',
#                                         'frame_id': '11e5ac42ae',
#                                         'height': '90',
#                                         'show_on_event_count': '1',
#                                         'width': '728'}},
#               'centerTop_14': {'name': 'feedcards/gutenberg'},
#               'centerTop_15': {'description': 'this module is used to set up '
#                                               'the dfp slots on the page',
#                                'dfp_ad_unit': '51859126/parent_ar_/child_ar_00/ar_100__3',
#                                'instance': '728x90_3',
#                                'name': 'ads/dfpslot',
#                                'vars': {'dfp_ad_unit': '51859126/parent_ar/child_ar_50/ar50_728x90_3',
#                                         'dfp_div_id': 'ar89_728x90_3',
#                                         'dfp_height': '90',
#                                         'dfp_width': '728'}},
#               'centerTop_2': {'description': 'Displays a list of guides by '
#                                              'category',
#                               'name': 'subject/title',
#                               'vars': {'smart_sizing': 'none',
#                                        'use_keyword': '0'}},
#               'centerTop_3': {'description': 'Gutenberg specific slideshow '
#                                              'using slide core functionality',
#                               'name': 'subject/desktop/slide',
#                               'vars': {'animation': 'show',
#                                        'button_color': 'red',
#                                        'button_color_hex': '',
#                                        'chunk_size': '50',
#                                        'combine_slides_into_one': 'on',
#                                        'dfp_height': '90',
#                                        'dfp_width': '728',
#                                        'image_param_string': 'w_688,c_fill,g_face:center,q_60,f_jpg',
#                                        'next_button_text': '<span '
#                                                            'class="button_text">NEXT</span><i '
#                                                            'class="fa '
#                                                            'fa-angle-double-right"></i>',
#                                        'prev_button_text': '<i class="fa '
#                                                            'fa-angle-double-left"></i><span '
#                                                            'class="button_text">PREVIOUS</span>',
#                                        'refresh_ads': 'no',
#                                        'slide_title_position': 'with_text',
#                                        'use_chunking': 'yes',
#                                        'use_one_page_article_link': 'on'}},
#               'centerTop_4': {'description': 'this module is used to set up '
#                                              'the dfp slots on the page',
#                               'dfp_ad_unit': '51859126/parent_ar_/child_ar_00/ar_100__2',
#                               'instance': 'to_move',
#                               'name': 'ads/dfpslot',
#                               'vars': {'dfp_ad_unit': '51859126/parent_ar/child_ar_50/ar50_728x90_2',
#                                        'dfp_div_id': 'ar50_728x90_4',
#                                        'dfp_height': '90',
#                                        'dfp_width': '728'}},
#               'centerTop_5': {'description': 'Simply places a block on the '
#                                              'page with whatever HTML (or css '
#                                              'and javascript) is configured. '
#                                              'Tokens available: {CURRENT_URL}',
#                               'instance': 'Outbrain',
#                               'name': 'html',
#                               'vars': {'payload': ' <div class="OUTBRAIN '
#                                                   'OUTBRAIN_0" data-src="" '
#                                                   'data-widget-id="AR_15" '
#                                                   'data-ob-template="answers" '
#                                                   '></div>\n'
#                                                   '\n'
#                                                   '<script>\n'
#                                                   '    var src = '
#                                                   'location.origin + '
#                                                   'location.pathname + '
#                                                   "'?variant=ar60';\n"
#                                                   '    '
#                                                   "$('.OUTBRAIN_0').attr('data-src', "
#                                                   'src);\n'
#                                                   '</script>\n'
#                                                   '\n'
#                                                   '<script '
#                                                   'type="text/javascript" '
#                                                   'async="async" '
#                                                   'src="http://widgets.outbrain.com/outbrain.js"></script>\n'
#                                                   '\n'
#                                                   '<script>\n'
#                                                   '    $(function() {\n'
#                                                   '        '
#                                                   "$('.ob-widget-items-container "
#                                                   "li a').on('click', "
#                                                   'function() {\n'
#                                                   '            '
#                                                   "$(this).parent('li').remove();\n"
#                                                   '        });\n'
#                                                   '    });\n'
#                                                   '</script>\n'
#                                                   '\n'
#                                                   '<style>\n'
#                                                   '    .AR_15.ob-widget {\n'
#                                                   '        margin: 0;\n'
#                                                   '    }\n'
#                                                   '    .ob-widget-header {\n'
#                                                   '        margin: 0 14px;\n'
#                                                   '    }\n'
#                                                   '    .AR_15.ob-widget '
#                                                   '.ob-widget-items-container '
#                                                   '{\n'
#                                                   '        display: inline;\n'
#                                                   '    }\n'
#                                                   '    .AR_15.ob-widget '
#                                                   '.ob-widget-items-container '
#                                                   '+ '
#                                                   '.ob-widget-items-container '
#                                                   'li {\n'
#                                                   '        margin-top: 10px;\n'
#                                                   '    }\n'
#                                                   '    .AR_15.ob-widget '
#                                                   '.ob-dynamic-rec-container '
#                                                   '{\n'
#                                                   '        width: 33.3333%;\n'
#                                                   '        max-width: none;\n'
#                                                   '        padding: 0 2%;\n'
#                                                   '        margin-left: 0 '
#                                                   '!important;\n'
#                                                   '    }\n'
#                                                   '</style>\n'}},
#               'centerTop_6': {'name': 'subject/editor/sidebar',
#                               'vars': {'show_follow_section': 'no',
#                                        'show_latest_section': 'no',
#                                        'user_id': '6390490'}},
#               'centerTop_7': {'description': 'Casale Ad slot for use outside '
#                                              'of DFP delivery',
#                               'name': 'links/casale',
#                               'vars': {'ad_description': 'index exchange '
#                                                          '728x90',
#                                        'ad_slot_name': 'casale_728x90_2',
#                                        'ad_units': '2',
#                                        'casale_id': '154714',
#                                        'casale_version': '2',
#                                        'height': '90',
#                                        'show_on_event_count': '1',
#                                        'width': '728'}},
#               'centerTop_8': {'name': 'subject/comment'},
#               'centerTop_9': {'name': 'subject/comment/add'},
#               'center_0': {'description': 'Feed Card Module Using Gutenberg '
#                                           'For Contents',
#                            'name': 'feedcards/gutenberg',
#                            'vars': {'card_count': '5',
#                                     'image_param_string': 'w_708,h_289,c_fill,g_face:center,q_60',
#                                     'image_service': 'cloudinary',
#                                     'max_answer_characters': '150',
#                                     'max_tagline_characters': '150'}},
#               'footer_0': {'description': 'Simply places a block on the page '
#                                           'with whatever HTML (or css and '
#                                           'javascript) is configured. Tokens '
#                                           'available: {CURRENT_URL}',
#                            'instance': 'under_image_positioner',
#                            'name': 'html',
#                            'vars': {'payload': '<script>\n'
#                                                '  \n'
#                                                '  (function() {\n'
#                                                '    var moveAdsTimeout;\n'
#                                                '    var slideTransitionEvents '
#                                                "= 'desktop_slide.slidenext "
#                                                'desktop_slide.slideprev '
#                                                'desktop_slide.prevarticle '
#                                                "desktop_slide.nextarticle';\n"
#                                                '\n'
#                                                '    var moveAds = function() '
#                                                '{\n'
#                                                '      var imageHeight = '
#                                                "$('.current_slide "
#                                                "img').height();\n"
#                                                '\n'
#                                                '      '
#                                                'window.clearTimeout(moveAdsTimeout);\n'
#                                                '\n'
#                                                '      if (imageHeight > 0) {\n'
#                                                '        var topHeightForImage '
#                                                '= imageHeight + '
#                                                "$('.subject_title').height() + "
#                                                '20;\n'
#                                                "        $('.to_move').css({\n"
#                                                '            '
#                                                "'top':topHeightForImage,\n"
#                                                '            '
#                                                "'position':'absolute'\n"
#                                                '        });         \n'
#                                                '      } else {\n'
#                                                '        moveAdsTimeout = '
#                                                'window.setTimeout(function() '
#                                                '{\n'
#                                                '          moveAds();\n'
#                                                '        }, 200);\n'
#                                                '      }\n'
#                                                '\n'
#                                                '    }\n'
#                                                '\n'
#                                                '    $(function() {\n'
#                                                '      moveAds();\n'
#                                                '      '
#                                                '$(document).on(slideTransitionEvents, '
#                                                'moveAds);\n'
#                                                '    });\n'
#                                                '  \n'
#                                                '  })();\n'
#                                                '  \n'
#                                                '</script>\n'}},
#               'footer_1': {'description': 'Refresh dfp and third-party ads',
#                            'name': 'ads/refresher',
#                            'vars': {'amazon_page_depth_refresh_start': '0',
#                                     'dfp_refresh_interval': '999999',
#                                     'dfp_timer_refresh_interval': '1500',
#                                     'max_dfp_consecutive_timed': '1',
#                                     'max_third_party_consecutive_timed': '1',
#                                     'refresh_counter_custom_variable': 'guteref',
#                                     'refresh_event_list': 'desktop_slide.slidenext,desktop_slide.slideprev,desktop_slide.prevarticle,desktop_slide.nextarticle',
#                                     'refresh_on_every_nth_click': '1',
#                                     'third_party_refresh_interval': '999999',
#                                     'timed_refresh_counter_custom_variable': 'gutetimedref'}},
#               'footer_2': {'description': 'Simply places a block on the page '
#                                           'with whatever HTML (or css and '
#                                           'javascript) is configured. Tokens '
#                                           'available: {CURRENT_URL}',
#                            'instance': 'share_taker_putter',
#                            'name': 'html',
#                            'vars': {'payload': '<style>\n'
#                                                '.image_wrapper_for_share{\n'
#                                                '    position: relative;\n'
#                                                '}\n'
#                                                '\n'
#                                                '.image_wrapper_for_share '
#                                                '.module.social_share_box {\n'
#                                                '    bottom: 15px;\n'
#                                                '    position: absolute;\n'
#                                                '    left: 15px;\n'
#                                                '    top: inherit;\n'
#                                                '}\n'
#                                                '</style>\n'
#                                                '\n'
#                                                '<script>\n'
#                                                '(function($){\n'
#                                                '    '
#                                                "if($('.module.social_share_box').length "
#                                                '> 0){\n'
#                                                '            var wrapForShare = '
#                                                'function(){\n'
#                                                "            $('.slide .image > "
#                                                "img').not('.share_took').each(function(){\n"
#                                                '                '
#                                                "$(this).wrap('<div "
#                                                'class="image_wrapper_for_share"></div>\');\n'
#                                                '                '
#                                                "$(this).addClass('share_took');\n"
#                                                '            });\n'
#                                                '\n'
#                                                '            '
#                                                "$('.image_wrapper_for_share').not('.share_took').each(function(){\n"
#                                                '                var $share = '
#                                                "$('.module.social_share_box').first().clone();\n"
#                                                '\n'
#                                                '                '
#                                                '$(this).append($share);\n'
#                                                '                '
#                                                "$(this).addClass('share_put');\n"
#                                                '            });\n'
#                                                '        };\n'
#                                                '\n'
#                                                '        wrapForShare();\n'
#                                                '\n'
#                                                '        '
#                                                "$(document).on('desktop_slide.nextajaxbatchafter', "
#                                                'wrapForShare);\n'
#                                                '    }\n'
#                                                '})(jQuery);\n'
#                                                '</script>\n'}},
#               'footer_3': {'name': 'tracking/pagebottom',
#                            'vars': {'comscore': '1',
#                                     'comscore_prefix': 'Answers.com_',
#                                     'quantcast': '1',
#                                     'tacoda': '1',
#                                     'tacoda_type': 'wa'}},
#               'header_0': {'description': 'Module used to set up DFP',
#                            'name': 'ads/dfpheader2',
#                            'vars': {'openx_bidder': 'yes'}},
#               'header_1': {'description': 'Simply places a block on the page '
#                                           'with whatever HTML (or css and '
#                                           'javascript) is configured. Tokens '
#                                           'available: {CURRENT_URL}',
#                            'instance': 'netseer',
#                            'name': 'html',
#                            'vars': {'payload': '<script '
#                                                'type="text/javascript">\n'
#                                                'netseer_tag_id="22196";\n'
#                                                'netseer_task="in-image";\n'
#                                                '</script>\n'
#                                                '<script type="text/javascript" '
#                                                'src="http://ps.ns-cdn.com/dsatserving2/scripts/netseerads.js"></script>\n'}},
#               'header_2': {'description': 'Simply places a block on the page '
#                                           'with whatever HTML (or css and '
#                                           'javascript) is configured. Tokens '
#                                           'available: {CURRENT_URL}',
#                            'name': 'html',
#                            'vars': {'location': 'head',
#                                     'payload': '\t<style type="text/css">\n'
#                                                '\n'
#                                                '\tbody { background-color: '
#                                                '#ebebeb;}\n'
#                                                '\t.thumbBlock_holder {\n'
#                                                '\t\twidth:100px !important;\n'
#                                                '\t\theight:100px !important;\n'
#                                                '\t\tfloat:left !important;\n'
#                                                "\t\tfont-family: 'Open Sans' "
#                                                '!important;\n'
#                                                '\t\tfont-size: 18px '
#                                                '!important;\n'
#                                                '\t\t\t\tmargin-top:10px '
#                                                '!important;\n'
#                                                '\t\t\t\tmargin-left: 13px '
#                                                '!important;\n'
#                                                '\t}\n'
#                                                '\t.video-title { padding-left: '
#                                                '10px;}\n'
#                                                '\t.branding { padding-left: '
#                                                '123px; text-transform: '
#                                                'uppercase;}\n'
#                                                '\n'
#                                                '\t.syndicatedItem { '
#                                                'background-color:white '
#                                                '!important;}\n'
#                                                '\tdiv[data-item-id] {\n'
#                                                '\n'
#                                                '\t\t-webkit-box-shadow: 0 2px '
#                                                '2px #afb0b2;\n'
#                                                '\t\t-moz-box-shadow: 0 2px 2px '
#                                                '#afb0b2;\n'
#                                                '\t\tbox-shadow: 0 2px 2px '
#                                                '#afb0b2;\n'
#                                                '\t\twidth: 100% !important;\n'
#                                                '\t\tmargin: 10px 0 0 0 '
#                                                '!important;\n'
#                                                '\t\tpadding: 10px 10px 0px '
#                                                '0px;\n'
#                                                '\t\ttext-align: left;\n'
#                                                '\t\tmin-height: 120px\n'
#                                                '\t}\n'
#                                                '\n'
#                                                '\n'
#                                                '\t</style>\n'
#                                                '\t<link '
#                                                "href='http://fonts.googleapis.com/css?family=Open+Sans:300italic,400italic,600italic,700italic,800italic,400,300,600,700,800' "
#                                                "rel='stylesheet' "
#                                                "type='text/css'>"}},
#               'header_3': {'description': '',
#                            'name': 'tracking/googleanalytics',
#                            'vars': {'custom_variable_1': 'null_mod_override_ar_35712',
#                                     'foresee_integration': 'on'}},
#               'header_4': {'name': 'js/metatags',
#                            'vars': {'page_type': 'gutenberg'}},
#               'header_5': {'name': 'js/head/scripts/home'},
#               'header_6': {'name': 'js/login'},
#               'header_7': {'name': 'header/redcarpet'},
#               'header_8': {'description': 'A tracking pixel module with '
#                                           'payloads',
#                            'name': 'tracking/pixel',
#                            'vars': {'noscript_payload': '\t <!-- Facebook '
#                                                         'Conversion Code for '
#                                                         'Red Carpet Test 1 '
#                                                         '-->\n'
#                                                         '<script>(function() '
#                                                         '{\n'
#                                                         '  var _fbq = '
#                                                         'window._fbq || '
#                                                         '(window._fbq = []);\n'
#                                                         '  if (!_fbq.loaded) '
#                                                         '{\n'
#                                                         '    var fbds = '
#                                                         "document.createElement('script');\n"
#                                                         '    fbds.async = '
#                                                         'true;\n'
#                                                         '    fbds.src = '
#                                                         "'//connect.facebook.net/en_US/fbds.js';\n"
#                                                         '    var s = '
#                                                         "document.getElementsByTagName('script')[0];\n"
#                                                         '    '
#                                                         's.parentNode.insertBefore(fbds, '
#                                                         's);\n'
#                                                         '    _fbq.loaded = '
#                                                         'true;\n'
#                                                         '  }\n'
#                                                         '})();\n'
#                                                         'window._fbq = '
#                                                         'window._fbq || [];\n'
#                                                         "window._fbq.push(['track', "
#                                                         "'6016313785447', "
#                                                         "{'value':'0.00','currency':'USD'}]);\n"
#                                                         '</script>\n'
#                                                         '<noscript><img '
#                                                         'height="1" width="1" '
#                                                         'alt="" '
#                                                         'style="display:none" '
#                                                         'src="https://www.facebook.com/tr?ev=6016313785447&amp;cd[value]=0.00&amp;cd[currency]=USD&amp;noscript=1" '
#                                                         '/></noscript>',
#                                     'slide_number': '1'}},
#               'header_9': {'description': 'Desired custom audience events',
#                            'name': 'tracking/fbcustomaudience',
#                            'vars': {'fb_audience_id': '481674938628832'}},
#               'left_0': {'description': 'this module is used to set up the dfp '
#                                         'slots on the page',
#                          'dfp_ad_unit': '51859126/parent_ar_/child_ar_00/ar_100__1',
#                          'instance': '160x600_1',
#                          'name': 'ads/dfpslot',
#                          'vars': {'dfp_ad_unit': '51859126/parent_ar/child_ar_50/ar50_160x600_1',
#                                   'dfp_div_id': 'ar89_160x600_1',
#                                   'dfp_height': '600',
#                                   'dfp_width': '160'}},
#               'left_1': {'description': 'The list of sibling categories for a '
#                                         'given guide url.',
#                          'name': 'subject/links',
#                          'vars': {'limit': '3'}},
#               'left_2': {'description': 'OpenX Ad slot for use outside of DFP '
#                                         'delivery',
#                          'instance': '160x600_2',
#                          'name': 'links/openx',
#                          'vars': {'ad_slot_name': 'expert_desktop_all_160x600_2',
#                                   'auid': '537088042',
#                                   'frame_id': '151e473a94',
#                                   'height': '600',
#                                   'show_on_event_count': '1',
#                                   'width': '160'}},
#               'left_3': {'name': 'user/controlpanel',
#                          'vars': {'my_pages_title': 'Quick Links',
#                                   'show_google_contributor_link': 'no',
#                                   'show_welcome': 'no'}},
#               'left_4': {'name': 'footer',
#                          'vars': {'version': 'side-condensed'}},
#               'left_5': {'description': 'Casale Ad slot for use outside of DFP '
#                                         'delivery',
#                          'name': 'links/casale',
#                          'vars': {'ad_description': 'Index Exchange: 160x600',
#                                   'ad_slot_name': 'casale_160x600',
#                                   'ad_units': '5',
#                                   'auid': '154714',
#                                   'casale_id': '154714',
#                                   'casale_version': '2',
#                                   'height': '600',
#                                   'show_on_event_count': '1',
#                                   'width': '160'}},
#               'left_6': {'name': 'links/site'},
#               'right_0': {'description': 'Video player that works',
#                           'instance': 'video_1 ads_dfpslot_1',
#                           'name': 'video/universal',
#                           'vars': {'ad_tag': 'http://vast.optimatic.com/vast/getVast.aspx?id=a253n547s864w&zone=<_sre.SRE_Match '
#                                              'object; span=(0, 4), '
#                                              "match='ar50'>&pageURL=__page-url__&pageTitle=__video-title__&cb=__random-number",
#                                    'auto_start': 'ON',
#                                    'player_height': '340',
#                                    'player_width': '540',
#                                    'playlist_id': '4'}},
#               'right_1': {'description': 'this module is used to set up the '
#                                          'dfp slots on the page',
#                           'dfp_ad_unit': '51859126/parent_ar_/child_ar_00/ar_100__1',
#                           'instance': 'first',
#                           'name': 'ads/dfpslot',
#                           'vars': {'dfp_ad_unit': '51859126/parent_ar/child_ar_50/ar50_300x250_1',
#                                    'dfp_div_id': 'ar89_300x250_1',
#                                    'dfp_height': '250',
#                                    'dfp_height_2': '600',
#                                    'dfp_width': '300',
#                                    'dfp_width_2': '300'}},
#               'right_2': {'description': 'This is a latest article by '
#                                          'specified root category ordered by '
#                                          'published_at desc',
#                           'name': 'subject/latest/articles',
#                           'vars': {'count': '1',
#                                    'heading': 'Latest Article',
#                                    'image_height': '120',
#                                    'image_width': '295'}},
#               'right_3': {'description': 'Casale Ad slot for use outside of '
#                                          'DFP delivery',
#                           'name': 'links/casale',
#                           'vars': {'ad_description': 'Index Exchange: 300x250',
#                                    'ad_slot_name': 'Casale_300x250',
#                                    'ad_units': '4',
#                                    'casale_id': '154714',
#                                    'casale_version': '2',
#                                    'height': '250',
#                                    'show_on_event_count': '1',
#                                    'width': '300'}},
#               'right_4': {'description': 'Simply places a block on the page '
#                                          'with whatever HTML (or css and '
#                                          'javascript) is configured. Tokens '
#                                          'available: {CURRENT_URL}',
#                           'name': 'html',
#                           'vars': {'payload': '<div class="fb-like" '
#                                               'data-width="200px" '
#                                               'data-layout="standard" '
#                                               'data-action="like" '
#                                               'data-show-faces="true" '
#                                               'data-share="false"></div>'}},
#               'right_5': {'description': 'OpenX Ad slot for use outside of DFP '
#                                          'delivery',
#                           'instance': '300x250_2',
#                           'name': 'links/openx',
#                           'vars': {'ad_slot_name': 'expert_desktop_all_300x250_2',
#                                    'auid': '537088040',
#                                    'frame_id': '936b44a4b4',
#                                    'height': '250',
#                                    'show_on_event_count': '1',
#                                    'width': '300'}},
#               'right_6': {'description': 'Simply places a block on the page '
#                                          'with whatever HTML (or css and '
#                                          'javascript) is configured. Tokens '
#                                          'available: {CURRENT_URL}',
#                           'instance': 'adblade',
#                           'name': 'html',
#                           'vars': {'payload': '<ins class="adbladeads" '
#                                               'data-cid="7647-2335177994" '
#                                               'data-host="web.adblade.com" '
#                                               'data-tag-type="1" '
#                                               'data-width="300" '
#                                               'data-height="400" '
#                                               'style="display:none"></ins>\n'
#                                               '<script async '
#                                               'src="http://web.adblade.com/js/ads/async/show.js" '
#                                               'type="text/javascript"></script>'}},
#               'right_7': {'description': 'Video player that works',
#                           'instance': 'video_2 ads_dfpslot_2',
#                           'name': 'video/universal',
#                           'vars': {'ad_tag': 'http://vast.optimatic.com/vast/getVast.aspx?id=a253n547s864w&zone=<_sre.SRE_Match '
#                                              'object; span=(0, 4), '
#                                              "match='ar50'>&pageURL=__page-url__&pageTitle=__video-title__&cb=__random-number",
#                                    'auto_start': 'ON',
#                                    'player_height': '340',
#                                    'player_width': '540',
#                                    'playlist_id': '4'}},
#               'right_8': {'description': 'Simply places a block on the page '
#                                          'with whatever HTML (or css and '
#                                          'javascript) is configured. Tokens '
#                                          'available: {CURRENT_URL}',
#                           'name': 'html',
#                           'vars': {'payload': '<a class="twitter-timeline" '
#                                               'href="https://twitter.com/AnswersCelebs" '
#                                               'data-widget-id="403931725958373376" '
#                                               'width="300" height="500" '
#                                               '>Tweets by @AnswersCelebs</a>\n'
#                                               '<script>!function(d,s,id){var '
#                                               'js,fjs=d.getElementsByTagName(s)[0],p=/^http:/.test(d.location)?\'http\':\'https\';if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src=p+"://platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");</script>\n'}},
#               'right_9': {'description': 'This is a latest article by '
#                                          'specified root category ordered by '
#                                          'published_at desc',
#                           'name': 'subject/latest/articles',
#                           'vars': {'image_height': '120',
#                                    'image_param_string': 'w_297,h_121,c_fill,g_face:center,q_60',
#                                    'image_width': '295'}}},
#  'selective_css': '1',
#  'skin': 'red-carpet',
#  'theme': '3-col-responsive'}

# %%
#new_json = open('json_out','w')
json_data = replaceDFPUnits_Mobile(json_dict,"gut_801")
pprint(json_data)

with open('outfile.json', 'w') as outfile:
    json.dump(json_data, outfile)
# Out:
# {'ads': 1,
#  'adsnip': {'click_tracking': 'on'},
#  'compactor': 'on',
#  'custom': {},
#  'partials': {'centerTop_0': {'name': 'carousel/ui/title'},
#               'centerTop_1': {'name': 'carousel/ui/img'},
#               'centerTop_10': {'description': 'Adds skin-specific Outbrain '
#                                               'tags',
#                                'name': 'ads/outbrain',
#                                'vars': {'variant': 'gut_801_1',
#                                         'widget': 'MB_2'}},
#               'centerTop_11': {'description': 'This is a latest article by '
#                                               'specified root category ordered '
#                                               'by published_at desc',
#                                'name': 'subject/latest/articles',
#                                'vars': {'count': '2',
#                                         'heading': 'Latest Articles',
#                                         'image_param_string': 'w_300,h_250,c_fill,g_face:center,q_60,f_jpg'}},
#               'centerTop_12': {'description': 'this module is used to set up '
#                                               'the dfp slots on the page',
#                                'instance': 'ad text-align-center adx no-vis-30 '
#                                            'labeled_ad sweetart2',
#                                'name': 'ads/dfpslot',
#                                'vars': {'dfp_ad_unit': '51859126/parent_m_ar/gut_801_3',
#                                         'dfp_div_id': '300x250_3',
#                                         'dfp_height': '250',
#                                         'dfp_height_2': '50',
#                                         'dfp_height_3': '50',
#                                         'dfp_height_4': '280',
#                                         'dfp_width': '300',
#                                         'dfp_width_2': '320',
#                                         'dfp_width_3': '300',
#                                         'dfp_width_4': '336'}},
#               'centerTop_13': {'description': 'This is a latest article by '
#                                               'specified root category ordered '
#                                               'by published_at desc',
#                                'name': 'subject/latest/articles',
#                                'vars': {'count': '2',
#                                         'image_param_string': 'w_300,h_250,c_fill,g_face:center,q_60,f_jpg',
#                                         'show_heading': 'no'}},
#               'centerTop_14': {'description': 'this module is used to set up '
#                                               'the dfp slots on the page',
#                                'instance': 'ad text-align-center adx no-vis-30 '
#                                            'labeled_ad sweetart2',
#                                'name': 'ads/dfpslot',
#                                'vars': {'dfp_ad_unit': '51859126/parent_m_ar/gut_801_4',
#                                         'dfp_div_id': '300x250_4',
#                                         'dfp_height': '250',
#                                         'dfp_height_2': '50',
#                                         'dfp_height_3': '50',
#                                         'dfp_height_4': '280',
#                                         'dfp_width': '300',
#                                         'dfp_width_2': '320',
#                                         'dfp_width_3': '300',
#                                         'dfp_width_4': '336'}},
#               'centerTop_15': {'description': 'This is a latest article by '
#                                               'specified root category ordered '
#                                               'by published_at desc',
#                                'name': 'subject/latest/articles',
#                                'vars': {'count': '2',
#                                         'image_param_string': 'w_300,h_250,c_fill,g_face:center,q_60,f_jpg',
#                                         'show_heading': 'no'}},
#               'centerTop_16': {'description': 'Ads Rubicon slot for use '
#                                               'outside of DFP delivery',
#                                'instance': 'ad text-align-center adx no-vis-30 '
#                                            'ad_with_label ad300_250 sweetart2',
#                                'name': 'ads/rubicon',
#                                'vars': {'ad_slot_name': 'Answers_com_MWeb_RFM_300x250_2_ROS',
#                                         'height': '250',
#                                         'iframe_class': 'rubicon_300x250_1',
#                                         'rp_kw': 'gut_801_5',
#                                         'width': '300'}},
#               'centerTop_17': {'description': 'This is a latest article by '
#                                               'specified root category ordered '
#                                               'by published_at desc',
#                                'name': 'subject/latest/articles',
#                                'vars': {'count': '2',
#                                         'image_param_string': 'w_300,h_250,c_fill,g_face:center,q_60,f_jpg',
#                                         'show_heading': 'no'}},
#               'centerTop_2': {'name': 'carousel/ui/subtitle'},
#               'centerTop_3': {'description': 'this module is used to set up '
#                                              'the dfp slots on the page',
#                               'instance': 'ad text-align-center labeled_ad',
#                               'name': 'ads/dfpslot',
#                               'vars': {'dfp_ad_unit': '51859126/parent_m_ar/gut_801_1',
#                                        'dfp_div_id': '300x250_1',
#                                        'dfp_height': '250',
#                                        'dfp_height_2': '50',
#                                        'dfp_height_3': '50',
#                                        'dfp_width': '300',
#                                        'dfp_width_2': '320',
#                                        'dfp_width_3': '300'}},
#               'centerTop_4': {'name': 'carousel/ui/text'},
#               'centerTop_5': {'description': 'this module is used to set up '
#                                              'the dfp slots on the page',
#                               'instance': 'ad text-align-center adx no-vis-10 '
#                                           'before_nav labeled_ad sweetart '
#                                           'near_nav',
#                               'name': 'ads/dfpslot',
#                               'vars': {'dfp_ad_unit': '51859126/parent_m_ar/gut_801_2',
#                                        'dfp_div_id': '300x250_2',
#                                        'dfp_height': '250',
#                                        'dfp_height_2': '50',
#                                        'dfp_height_3': '50',
#                                        'dfp_height_4': '280',
#                                        'dfp_width': '300',
#                                        'dfp_width_2': '320',
#                                        'dfp_width_3': '300',
#                                        'dfp_width_4': '336'}},
#               'centerTop_6': {'description': 'Display an open or close div '
#                                              'tag, used to wrap modules in a '
#                                              'div',
#                               'instance': 'carousel_slideshow_buttons clearfix',
#                               'name': 'utility/wrapper',
#                               'vars': {'class': '', 'id': ''}},
#               'centerTop_7': {'description': 'flight componenet for navigating '
#                                              'backwards through a carousel',
#                               'name': 'carousel/ui/buttons/previous',
#                               'vars': {'button_text': 'PREV'}},
#               'centerTop_8': {'name': 'carousel/ui/buttons/next'},
#               'centerTop_9': {'description': 'Display an open or close div '
#                                              'tag, used to wrap modules in a '
#                                              'div',
#                               'instance': 'close',
#                               'name': 'utility/wrapper',
#                               'vars': {'class': '', 'id': '', 'type': 'close'}},
#               'footer_0': {'description': 'Simply places a block on the page '
#                                           'with whatever HTML (or css and '
#                                           'javascript) is configured. Tokens '
#                                           'available: {CURRENT_URL}',
#                            'instance': 'fban fban_interstitial',
#                            'name': 'html',
#                            'vars': {'location': 'feet',
#                                     'payload': '<script>\n'
#                                                'var fban_interstitial_config = '
#                                                '{\n'
#                                                "    'placementid': "
#                                                "'168416999909992_972806032804414',\n"
#                                                '\n'
#                                                "    'trigger_on_timer': "
#                                                'false,\n'
#                                                "    'timer_seconds': null,\n"
#                                                '\n'
#                                                "    'trigger_on_slide_change': "
#                                                'true,\n'
#                                                "    'slide_count_start': 5,\n"
#                                                '    '
#                                                "'slide_count_repeat_interval': "
#                                                '5\n'
#                                                '};\n'
#                                                '</script>\n'
#                                                '<style>\n'
#                                                '.module.fban_interstitial {\n'
#                                                '  display: block;\n'
#                                                '  background: white;\n'
#                                                '  height: 0;\n'
#                                                '  width: 0;\n'
#                                                '  position: absolute;\n'
#                                                '  overflow: hidden;\n'
#                                                '  z-index: -999;\n'
#                                                '  opacity: 0;\n'
#                                                '  margin: 0;\n'
#                                                '  padding: 0;\n'
#                                                '  border: none;\n'
#                                                '}\n'
#                                                '.module.fban_interstitial.adloaded '
#                                                '{\n'
#                                                '  height: 100%;\n'
#                                                '  width: 100%;\n'
#                                                '  height: '
#                                                '-webkit-calc(100vh);\n'
#                                                '  width: -webkit-calc(100vw);\n'
#                                                '  height: calc(100vh);\n'
#                                                '  width: calc(100vw);\n'
#                                                '  position: fixed;\n'
#                                                '  top: 0;\n'
#                                                '  right: 0;\n'
#                                                '  bottom: 0;\n'
#                                                '  left: 0;\n'
#                                                '  z-index: 999;\n'
#                                                '  opacity: 1;\n'
#                                                '  display: none;\n'
#                                                '}\n'
#                                                '.isMobileSafari '
#                                                '.module.fban_interstitial.adloaded '
#                                                '{\n'
#                                                '  height: 100%;\n'
#                                                '  width: 100%;\n'
#                                                '}\n'
#                                                '.module.fban_interstitial '
#                                                '.fb_iframe_widget {\n'
#                                                '  position: absolute;\n'
#                                                '  top: -30px;\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fban_interstitial_close {\n'
#                                                '  position: absolute;\n'
#                                                '  top: 5px;\n'
#                                                '  right: 5px;\n'
#                                                '  padding: 5px;\n'
#                                                '  text-align: center;\n'
#                                                '  cursor: pointer;\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fban_interstitial_close span '
#                                                '{\n'
#                                                '  font-family: Arial, '
#                                                'sans-serif;\n'
#                                                '  font-size: 40px;\n'
#                                                '  font-weight: normal;\n'
#                                                '  background: rgba(0,0,0, '
#                                                '0.33);\n'
#                                                '  box-shadow: 0 0 3px '
#                                                'rgba(255,255,255, 0.2);\n'
#                                                '  color: #eee;\n'
#                                                '  border-radius: 50px;\n'
#                                                '  display: block;\n'
#                                                '  width: 50px;\n'
#                                                '  height: 50px;\n'
#                                                '  line-height: 50px;\n'
#                                                '  overflow: hidden;\n'
#                                                '}\n'
#                                                '.fban_interstitial .fbAdLink '
#                                                '{\n'
#                                                '  display: block;\n'
#                                                '  height: 100%;\n'
#                                                '  width: 100%;\n'
#                                                '}\n'
#                                                '.fban_interstitial .fbAdMedia '
#                                                '{\n'
#                                                '  background: center center '
#                                                'no-repeat;\n'
#                                                '  background-size: cover;\n'
#                                                '  -webkit-animation: '
#                                                'paninterstitial 10s infinite;\n'
#                                                '  '
#                                                '-webkit-animation-timing-function: '
#                                                'ease-in-out;\n'
#                                                '  animation: paninterstitial '
#                                                '10s infinite;\n'
#                                                '  animation-timing-function: '
#                                                'ease-in-out;\n'
#                                                '  position: relative;\n'
#                                                '  padding: 0 0 75% 0; /* 4:3 '
#                                                '*/\n'
#                                                '  height: 0;\n'
#                                                '  box-shadow: inset 0 0px 35px '
#                                                'rgba(0,0,0,.2);\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fban_interstitial_top {\n'
#                                                '  position: relative;\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fban_interstitial_top '
#                                                '.fbAdIcon {\n'
#                                                '  text-align: center;\n'
#                                                '  position: absolute;\n'
#                                                '  bottom: -35px;\n'
#                                                '  width: 100%;\n'
#                                                '}\n'
#                                                '.fban_interstitial .fbAdIcon '
#                                                'img {\n'
#                                                '  width: 60px !important;\n'
#                                                '  height: 60px !important;\n'
#                                                '  margin: auto;\n'
#                                                '  box-shadow: 0 3px 8px '
#                                                'rgba(0,0,0,.3);\n'
#                                                '  -webkit-box-sizing: '
#                                                'content-box;\n'
#                                                '  box-sizing: content-box;\n'
#                                                '  border: 1px solid #333;\n'
#                                                '  outline: 3px solid #fff;\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fban_interstitial_body {\n'
#                                                '    color: #666;\n'
#                                                '    font-size: 13px;\n'
#                                                '    padding: 40px 20px 0;\n'
#                                                '    text-align: center;\n'
#                                                '}\n'
#                                                '.fban_interstitial .fbAdTitle '
#                                                '{\n'
#                                                '    color: #333;\n'
#                                                '    font-size: 18px;\n'
#                                                '    font-weight: bold;\n'
#                                                '    padding: 10px 0 15px;\n'
#                                                '    letter-spacing: -.05em;\n'
#                                                '    line-height: 1.5em;\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fbAdSubtitle {\n'
#                                                '    display: none;\n'
#                                                '    color: #999;\n'
#                                                '    margin-top: -10px;\n'
#                                                '    margin-bottom: 10px;\n'
#                                                '    letter-spacing: .04em;\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fbAdSocialContext {\n'
#                                                '    color: #999;\n'
#                                                '    margin-top: -10px;\n'
#                                                '    margin-bottom: 10px;\n'
#                                                '    letter-spacing: .04em;\n'
#                                                '    text-decoration: '
#                                                'underline;\n'
#                                                '}\n'
#                                                '.fban_interstitial .fbAdBody '
#                                                '{\n'
#                                                '    font-size: 16px;\n'
#                                                '    line-height: 1.5em;\n'
#                                                '    padding: 15px 0;\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fbAdCallToActionWrapper {\n'
#                                                '    background: '
#                                                'rgba(255,255,255,.8);\n'
#                                                '    position: absolute;\n'
#                                                '    bottom: 0;\n'
#                                                '    width: 100%;\n'
#                                                '    padding: 20px 10px 25px;\n'
#                                                '    text-align: center;\n'
#                                                '    box-shadow: 0 0 30px '
#                                                'rgba(0,0,0,0.1);\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fbAdCallToActionWrapper '
#                                                '.fbAdIcon {\n'
#                                                '    display: none;\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fbAdCallToAction {\n'
#                                                '    position: relative;\n'
#                                                '    color: #ffffff;\n'
#                                                '    text-decoration: none;\n'
#                                                "    font-family: 'Oswald', "
#                                                "'Helvetica Neue', 'Open Sans', "
#                                                "'Arial';\n"
#                                                '    display: block;\n'
#                                                '    border-radius: 6px;\n'
#                                                '    text-align: center;\n'
#                                                '    -webkit-transform: '
#                                                'translate(0, 0);\n'
#                                                '    -moz-transform: '
#                                                'translate(0, 0);\n'
#                                                '    transform: translate(0, '
#                                                '0);\n'
#                                                '    transition: all .2s ease;\n'
#                                                '    cursor: pointer;\n'
#                                                '    overflow: hidden;\n'
#                                                '    text-shadow: none;\n'
#                                                '    box-shadow: 0px 6px 0px '
#                                                'rgb(44, 193, 45);\n'
#                                                '    background: rgb(72, 212, '
#                                                '73);\n'
#                                                '    border: none;\n'
#                                                '    outline: none;\n'
#                                                '    white-space: nowrap;\n'
#                                                '    padding: 7px 30px 4px;\n'
#                                                '    letter-spacing: .1em;\n'
#                                                '    margin: auto;\n'
#                                                '    z-index: 999;\n'
#                                                '}\n'
#                                                '.fban_interstitial '
#                                                '.fbAdCallToAction:active {\n'
#                                                '    box-shadow: 0px 2px 0px '
#                                                'rgb(44, 193, 45);\n'
#                                                '}\n'
#                                                '@-webkit-keyframes '
#                                                'paninterstitial {\n'
#                                                '    0% { background-position: '
#                                                '50%; }\n'
#                                                '    20% { background-position: '
#                                                '50%; }\n'
#                                                '    30% { background-position: '
#                                                '0%; }\n'
#                                                '    70% { background-position: '
#                                                '100%; }\n'
#                                                '    80% { background-position: '
#                                                '50%; }\n'
#                                                '    100% { '
#                                                'background-position: 50%; }\n'
#                                                '}\n'
#                                                '@keyframes paninterstitial {\n'
#                                                '    0% { background-position: '
#                                                '50%; }\n'
#                                                '    20% { background-position: '
#                                                '50%; }\n'
#                                                '    30% { background-position: '
#                                                '0%; }\n'
#                                                '    70% { background-position: '
#                                                '100%; }\n'
#                                                '    80% { background-position: '
#                                                '50%; }\n'
#                                                '    100% { '
#                                                'background-position: 50%; }\n'
#                                                '}\n'
#                                                '\n'
#                                                '\n'
#                                                '@media (orientation: '
#                                                'landscape) {\n'
#                                                '    .fban_interstitial '
#                                                '.fbAdMediaWrapper {\n'
#                                                '      height: 100%;\n'
#                                                '        position: absolute;\n'
#                                                '        top: 0;\n'
#                                                '        bottom: 0;\n'
#                                                '        left: 0;\n'
#                                                '        right: 0;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fbAdMedia {\n'
#                                                '      height: 100%;\n'
#                                                '        position: absolute;\n'
#                                                '        top: 0;\n'
#                                                '        bottom: 0;\n'
#                                                '        left: 0;\n'
#                                                '        right: 0;\n'
#                                                '      padding: 0;\n'
#                                                '      height: auto;\n'
#                                                '      background-size: '
#                                                'contain;\n'
#                                                '      background-color: #000;\n'
#                                                '      -webkit-animation: '
#                                                'none;\n'
#                                                '      animation: none;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fban_interstitial_top {\n'
#                                                '      position: absolute;\n'
#                                                '      top: 0;\n'
#                                                '      right: 0;\n'
#                                                '      bottom: 70px;\n'
#                                                '      left: 0;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fban_interstitial_top '
#                                                '.fbAdIcon {\n'
#                                                '      position: absolute;\n'
#                                                '      top: 0;\n'
#                                                '      right: 0;\n'
#                                                '      bottom: 70px;\n'
#                                                '      left: 0;\n'
#                                                '      display: none;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fban_interstitial_body {\n'
#                                                '      position: absolute;\n'
#                                                '      width: auto;\n'
#                                                '      padding: 0;\n'
#                                                '      bottom: 0px;\n'
#                                                '      left: 70px;\n'
#                                                '      right: 110px;\n'
#                                                '      text-align: left;\n'
#                                                '      z-index: 999;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fbAdTitle {\n'
#                                                '      padding: 10px 0;\n'
#                                                '      font-size: 15px;\n'
#                                                '      font-weight: normal;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fbAdSubtitle,\n'
#                                                '    .fban_interstitial '
#                                                '.fbAdBody {\n'
#                                                '        display: none;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fbAdCallToActionWrapper {\n'
#                                                '      height: 70px;\n'
#                                                '      padding: 0 10px;\n'
#                                                '      text-align: right;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fbAdCallToActionWrapper '
#                                                '.fbAdIcon {\n'
#                                                '      display: block;\n'
#                                                '      width: 50px;\n'
#                                                '      height: 50px;\n'
#                                                '      position: absolute;\n'
#                                                '      left: 10px;\n'
#                                                '      top: 10px;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fbAdCallToActionWrapper '
#                                                'button {\n'
#                                                '      margin: 0;\n'
#                                                '      position: absolute;\n'
#                                                '      top: 10px;\n'
#                                                '      right: 10px;\n'
#                                                '      bottom: 15px;\n'
#                                                '      padding: 0 10px;\n'
#                                                '      font-weight: normal;\n'
#                                                '      font-size: 14px;\n'
#                                                '    }\n'
#                                                '    .fban_interstitial '
#                                                '.fbAdCallToActionWrapper '
#                                                '.fbAdIcon img {\n'
#                                                '      height: 100% '
#                                                '!important;\n'
#                                                '      width: 100% !important;\n'
#                                                '    }\n'
#                                                '}\n'
#                                                '</style>\n'
#                                                '\n'
#                                                '<div '
#                                                'id="fban_interstitial_template" '
#                                                'class="module html '
#                                                'fban_interstitial">\n'
#                                                '    <fb:ad\n'
#                                                '        '
#                                                'nativeadid="fban_unit_interstitial_1"\n'
#                                                '        placementid=""\n'
#                                                '        format="native"\n'
#                                                '        '
#                                                'testmode="false"></fb:ad>\n'
#                                                '    <div '
#                                                'id="fban_unit_interstitial_1">\n'
#                                                '      <a class="fbAdLink">\n'
#                                                '        <div '
#                                                'class="fban_interstitial_top">\n'
#                                                '            <div '
#                                                'class="fbAdMedia"></div>\n'
#                                                '            <div '
#                                                'class="fbAdIcon"></div>\n'
#                                                '        </div>\n'
#                                                '        <div '
#                                                'class="fban_interstitial_body">\n'
#                                                '          <div '
#                                                'class="fbAdTitle"></div>\n'
#                                                '          <div '
#                                                'class="fbAdSocialContext"></div>\n'
#                                                '          <div '
#                                                'class="fbAdSubtitle"></div>\n'
#                                                '          <div '
#                                                'class="fbAdBody"></div>\n'
#                                                '        </div>\n'
#                                                '        <div '
#                                                'class="fbAdCallToActionWrapper">\n'
#                                                '            <div '
#                                                'class="fbAdIcon"></div>\n'
#                                                '            <button '
#                                                'class="fbAdCallToAction"></button>\n'
#                                                '        </div>\n'
#                                                '      </a>\n'
#                                                '      <div '
#                                                'class="fban_interstitial_close" '
#                                                'aria-label="Close '
#                                                'Ad"><span>Ã—</span></div>\n'
#                                                '    </div>\n'
#                                                '</div>\n'
#                                                '\n'
#                                                '\n'
#                                                '<script>\n'
#                                                '(function(){\n'
#                                                '    var config = '
#                                                'fban_interstitial_config;\n'
#                                                '    var $template = '
#                                                "$('#fban_interstitial_template');\n"
#                                                '    if(!config.placementid){\n'
#                                                '      $template.hide();\n'
#                                                '      return;\n'
#                                                '    }\n'
#                                                '    '
#                                                "$template.find('fb\\\\:ad').attr('placementid', "
#                                                'config.placementid);\n'
#                                                '    var fbani_template = '
#                                                "$('#fban_interstitial_template').html();\n"
#                                                '    var slide_change_count = '
#                                                '1;\n'
#                                                '    var first_shown = false;\n'
#                                                '    function isMobileSafari() '
#                                                '{\n'
#                                                '      return '
#                                                'navigator.userAgent.match(/(iPod|iPhone|iPad)/) '
#                                                '&& '
#                                                'navigator.userAgent.match(/AppleWebKit/);\n'
#                                                '    }\n'
#                                                '    if(isMobileSafari()){\n'
#                                                '      '
#                                                "$('body').addClass('isMobileSafari');\n"
#                                                '    }\n'
#                                                '    '
#                                                'if(config.trigger_on_slide_change){\n'
#                                                '        $([document, '
#                                                "document.body]).on('carousel_slide_change', "
#                                                'function(){\n'
#                                                '            '
#                                                'slide_change_count++;\n'
#                                                '            '
#                                                "if(!$('.module.fban_interstitial.adloaded:first').length){\n"
#                                                '                '
#                                                'fban_interstitial_refresh();\n'
#                                                '            }else{\n'
#                                                '                '
#                                                'if(!first_shown){\n'
#                                                '                    '
#                                                'if(!isNaN(config.slide_count_start)){\n'
#                                                '                        '
#                                                'if(slide_change_count >= '
#                                                'config.slide_count_start){\n'
#                                                '                            '
#                                                "$(document).trigger('fban_show_interstitial');\n"
#                                                '                        }\n'
#                                                '                    }\n'
#                                                '                }else '
#                                                'if(!isNaN(config.slide_count_repeat_interval)){\n'
#                                                '                    '
#                                                'if(slide_change_count >= '
#                                                'config.slide_count_repeat_interval){\n'
#                                                '                        '
#                                                "$(document).trigger('fban_show_interstitial');\n"
#                                                '                    }\n'
#                                                '                }\n'
#                                                '            }\n'
#                                                '        });\n'
#                                                '    }\n'
#                                                '    FB.Event.subscribe(\n'
#                                                "        'ad.loaded',\n"
#                                                '        function(placementid) '
#                                                '{\n'
#                                                '            if(placementid !== '
#                                                'config.placementid){\n'
#                                                '              return;\n'
#                                                '            }\n'
#                                                '            var $fbani = '
#                                                "$('.module.fban_interstitial:first');\n"
#                                                '            '
#                                                "if($fbani.find('.fbAdTitle:first').text() "
#                                                "=== ''){\n"
#                                                '                // LIARS!\n'
#                                                '                // '
#                                                "console.log('FBAN: no ad "
#                                                "title');\n"
#                                                '                '
#                                                'fban_interstitial_refresh();\n'
#                                                '                return;\n'
#                                                '            }\n'
#                                                '            var $img = '
#                                                "$fbani.find('.fbAdMedia "
#                                                "img');\n"
#                                                '            if($img.length){\n'
#                                                '                $fbani\n'
#                                                '                    '
#                                                ".find('.fbAdMedia')\n"
#                                                '                    '
#                                                ".css({'background-image':'url('+JSON.stringify($img.attr('src'))+')'});\n"
#                                                '                '
#                                                "$img.css('opacity',0);\n"
#                                                '            }else{\n'
#                                                '                // Broken .. '
#                                                'not showing\n'
#                                                '                // '
#                                                "console.log('FBAN: bad "
#                                                "fbAdMedia', "
#                                                "$fbani.find('.fbAdMedia').html());\n"
#                                                '                '
#                                                'fban_interstitial_refresh();\n'
#                                                '                return;\n'
#                                                '            }\n'
#                                                '            '
#                                                "$fbani.addClass('adloaded');\n"
#                                                '            // special case '
#                                                'for onpageload display\n'
#                                                '            if(\n'
#                                                '                '
#                                                'config.trigger_on_slide_change \n'
#                                                '                && '
#                                                '!first_shown \n'
#                                                '                && '
#                                                'config.slide_count_start === '
#                                                '1 \n'
#                                                '                && '
#                                                'slide_change_count === 1\n'
#                                                '            ){\n'
#                                                '                '
#                                                "$(document).trigger('fban_show_interstitial');\n"
#                                                '            }\n'
#                                                '        }\n'
#                                                '    );\n'
#                                                '    FB.Event.subscribe(\n'
#                                                "        'ad.error',\n"
#                                                '        function(errorCode, '
#                                                'errorMessage, placementid) {\n'
#                                                '            // '
#                                                "console.log('ad.error', "
#                                                'arguments);\n'
#                                                '            if(placementid !== '
#                                                'config.placementid){\n'
#                                                '              return;\n'
#                                                '            }\n'
# ...
#                                                '\t\t-webkit-transform: '
#                                                'translate(0, -50%);\n'
#                                                '\t\t-moz-transform: '
#                                                'translate(0, -50%);\n'
#                                                '\t\t-ms-transform: '
#                                                'translate(0, -50%);\n'
#                                                '\t\t-o-transform: translate(0, '
#                                                '-50%);\n'
#                                                '\t\ttransform: translate(0, '
#                                                '-50%);\n'
#                                                '\t}\n'
#                                                '\n'
#                                                '\n'
#                                                '\t/** FORMAT TOGGLE STYLES '
#                                                '**/\n'
#                                                '\t.format_toggle .option {\n'
#                                                '\t\tdisplay: block;\n'
#                                                '\t\tfloat: left;\n'
#                                                '\t\tpadding: 8px 6px;\n'
#                                                '\t\tbackground-color: '
#                                                '#1E78D7;\n'
#                                                '\t\tborder: 1px solid '
#                                                '#0854cf;\n'
#                                                '\t\ttext-align: center;\n'
#                                                '\t\tfont-size: .75em;\n'
#                                                '\t\ttext-decoration: none;\n'
#                                                '\t\tcolor: #fff;\n'
#                                                '\n'
#                                                '\t\t-webkit-transition: '
#                                                'border-color 50ms;\n'
#                                                '\t\t-moz-transition: '
#                                                'border-color 50ms;\n'
#                                                '\t\ttransition: border-color '
#                                                '50ms;\n'
#                                                '\t}\n'
#                                                '\t.format_toggle .option:hover '
#                                                '{\n'
#                                                '\t\tbackground-color: '
#                                                '#d7d8d8;\n'
#                                                '\t\tcolor: #fff;\n'
#                                                '\t}\n'
#                                                '\t.format_toggle '
#                                                '.option:first-child {\n'
#                                                '\t\tborder-radius: 3px 0 0 '
#                                                '3px;\n'
#                                                '\t}\n'
#                                                '\t.format_toggle '
#                                                '.option:nth-child(2) {\n'
#                                                '\t\tborder-right-width: 0;\n'
#                                                '\t\tborder-left-width: 0;\n'
#                                                '\t}\n'
#                                                '\t.format_toggle '
#                                                '.option:last-child {\n'
#                                                '\t\tborder-radius: 0 3px 3px '
#                                                '0;\n'
#                                                '\t}\n'
#                                                '\t.format_toggle '
#                                                '.option.selected {\n'
#                                                '\t\tbackground-color: '
#                                                '#1562D2;\n'
#                                                '\t\tborder-color: #0854cf;\n'
#                                                '\t\tcolor: #fff;\n'
#                                                '\t}\n'
#                                                '\t.format_toggle '
#                                                '.option.disabled {\n'
#                                                '\t\tpointer-events: none;\n'
#                                                '\t\tcursor: default;\n'
#                                                '\t}\n'
#                                                '\t.format_toggle '
#                                                '.option.disabled:hover {\n'
#                                                '\t\tcolor: #c3c4c5 '
#                                                '!important;\n'
#                                                '\t}\n'
#                                                '\n'
#                                                '\t.format_toggle .option .fa '
#                                                '{\n'
#                                                '\t\tposition: relative;\n'
#                                                '\t\ttop: -1px;\n'
#                                                '\t}\n'
#                                                '</style>\n'
#                                                '\n'
#                                                '<header '
#                                                'class="header_mobile_gute '
#                                                'clearfix">\n'
#                                                '\t<figure class="logo">\n'
#                                                '\t\t<a track="home_tools/PAGE" '
#                                                'title="Answers.com home" '
#                                                'href="http://www.answers.com">\n'
#                                                '\t\t\t<svg width="115" '
#                                                'height="30">\n'
#                                                '\t\t\t\t<image '
#                                                'xmlns:xlink="http://www.w3.org/1999/xlink" '
#                                                'xlink:href="//rxs1.answcdn.com/includes/images/redcarpet/answers-logo-white.svg" '
#                                                'width="115" height="30" '
#                                                'src="//rxs1.answcdn.com/includes/images/onboarding/answers-logo-white.png">\n'
#                                                '\t\t\t</svg>\n'
#                                                '\t\t</a>\n'
#                                                '\t</figure>\n'
#                                                '</header>\n'
#                                                '\n'
#                                                '\n'
#                                                '\n'
#                                                '<script>\n'
#                                                '\t(function() {\n'
#                                                '\n'
#                                                '\t\tvar getLmi = function() {\n'
#                                                '\t\t\treturn '
#                                                'decodeURIComponent(document.cookie.replace(new '
#                                                'RegExp("(?:(?:^|.*;)\\\\s*" + '
#                                                "encodeURIComponent('mode_id').replace(/[\\-\\.\\+\\*]/g, "
#                                                '"\\\\$&") + '
#                                                '"\\\\s*\\\\=\\\\s*([^;]*).*$)|^.*$"), '
#                                                '"$1")) || null;\n'
#                                                '\t\t};\n'
#                                                '\n'
#                                                '\t\tvar getPostId = function() '
#                                                '{\n'
#                                                '\t\t\tvar id = '
#                                                "location.pathname.split('/')[2];\n"
#                                                '\n'
#                                                '\t\t\tif (isNaN(id) === true) '
#                                                '{\n'
#                                                '\t\t\t\tid = '
#                                                "$('.current_batch').data('batch-id') "
#                                                '|| 0;\n'
#                                                '\t\t\t}\n'
#                                                '\n'
#                                                '\t\t\treturn id;\n'
#                                                '\t\t};\n'
#                                                '\n'
#                                                '\t\tvar check_videos = '
#                                                'function () {\n'
#                                                '\t\t\t$(function () {\n'
#                                                "\t\t\t\tvar url =  '//' + "
#                                                'location.host + '
#                                                "'/endpoint/guides/posts/sections',\n"
#                                                '\t\t\t\t\tid = getPostId();\n'
#                                                '\n'
#                                                '\t\t\t\t$.ajax({\n'
#                                                '\t\t\t\t\turl: url,\n'
#                                                "\t\t\t\t\ttype: 'GET',\n"
#                                                "\t\t\t\t\tdataType: 'json',\n"
#                                                '\t\t\t\t\tdata: {posts_id: '
#                                                'id},\n'
#                                                '\t\t\t\t\terror: function '
#                                                '(one, two, three) {\n'
#                                                '\t\t\t\t\t},\n'
#                                                '\t\t\t\t\tsuccess: function '
#                                                '(data) {\n'
#                                                '\t\t\t\t\t\tif (data.error) {\n'
#                                                '\t\t\t\t\t\t\t'
#                                                "$('.format_toggle "
#                                                ".option.video').remove();\n"
#                                                '\t\t\t\t\t\t\t'
#                                                "$('.format_toggle').addClass('thin');\n"
#                                                '\t\t\t\t\t\t\treturn false;\n'
#                                                '\t\t\t\t\t\t}\n'
#                                                '\n'
#                                                '\t\t\t\t\t\tvar results = '
#                                                'data.result,\n'
#                                                '\t\t\t\t\t\t\tlen = '
#                                                'results.length,\n'
#                                                '\t\t\t\t\t\t\ti=0;\n'
#                                                '\n'
#                                                '\t\t\t\t\t\tfor (; i < len; '
#                                                'i++) {\n'
#                                                '\t\t\t\t\t\t\tvar d = '
#                                                'results[i];\n'
#                                                '\n'
#                                                '\t\t\t\t\t\t\tif (d.type === '
#                                                "'video') {\n"
#                                                '\t\t\t\t\t\t\t\t'
#                                                "$('.format_toggle "
#                                                ".option.video').removeClass('disabled');\n"
#                                                '\t\t\t\t\t\t\t\treturn true;\n'
#                                                '\t\t\t\t\t\t\t}\n'
#                                                '\t\t\t\t\t\t}\n'
#                                                '\t\t\t\t\t}\n'
#                                                '\t\t\t\t});\n'
#                                                '\t\t\t});\n'
#                                                '\t\t};\n'
#                                                '\n'
#                                                '\t\tvar initialize = '
#                                                'function() {\n'
#                                                '\t\t\t$(function () {\n'
#                                                '\t\t\t\t'
#                                                "$('.controls').children().each(function() "
#                                                '{\n'
#                                                '\t\t\t\t\t'
#                                                '$(this).click(function(e) {\n'
#                                                '\t\t\t\t\t\tvar type = '
#                                                "$(e.target).attr('data-type');\n"
#                                                '\t\t\t\t\t\t'
#                                                "_gaq.push(['_trackEvent', "
#                                                "'Article Format', type + ' "
#                                                "click', 'param4-' + getLmi() + "
#                                                "'-' + getPostId() + '-' + "
#                                                'type]);\n'
#                                                '\t\t\t\t\t});\n'
#                                                '\t\t\t\t});\n'
#                                                '\t\t\t});\n'
#                                                '\t\t};\n'
#                                                '\n'
#                                                '\t\tinitialize();\n'
#                                                '\t\tcheck_videos();\n'
#                                                '\n'
#                                                '\t}());\n'
#                                                '</script>'}},
#               'header_3': {'name': 'js/head/scripts/home'},
#               'header_4': {'name': 'js/login'},
#               'header_5': {'name': 'js/decoderedirect'},
#               'header_6': {'description': '',
#                            'name': 'tracking/googleanalytics',
#                            'vars': {'custom_variable_1': 'null_mod_override_ar_55825',
#                                     'track_fb_status': 'off'}},
#               'header_7': {'name': 'js/metatags',
#                            'vars': {'keyword-title-suffix': '',
#                                     'page_type': 'gutenberg',
#                                     'profile_title_suffix': ''}},
#               'header_8': {'description': 'Module for configuring a Gutenberg '
#                                           'article slideshow and adapting data '
#                                           'to presentation.',
#                            'name': 'carousel/slideshow',
#                            'vars': {'chunk_on_punctuation': 'yes',
#                                     'image_param_string': 'w_728,c_fill,g_face:center,q_60,f_jpg',
#                                     'make_section_title_a_pane': 'no',
#                                     'text_chunk_size': '100'}},
#               'header_9': {'description': 'this module is used to set up the '
#                                           'dfp slots on the page',
#                            'instance': 'dfp_1x1',
#                            'name': 'ads/dfpslot',
#                            'vars': {'dfp_ad_unit': '/51859126/answ_mobile_1x1',
#                                     'dfp_div_id': 'answ_mobile_1x1',
#                                     'dfp_height': '1',
#                                     'dfp_width': '1'}}},
#  'selective_css': '1',
#  'skin': 'red-carpet',
#  'theme': '3-col-responsive'}
